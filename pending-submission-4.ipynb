# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/bttai-ajl-2025'):
    print(dirname)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Stuff to reload when you revisit the model

import pandas as pd
import pickle
import json
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import LabelEncoder

# model
model = load_model('final_efficientnetb3_model.keras')

# label encoder
with open('label_encoder.pkl', 'rb') as f:
    label_encoder = pickle.load(f)

# train/val data
train_df = pd.read_csv('train_df.csv')
train_data = pd.read_csv('train_data.csv')
val_data = pd.read_csv('val_data.csv')

# training history
with open('history_finetune.json', 'r') as f:
    history_finetune = json.load(f)

train_data['encoded_label'] = train_data['encoded_label'].astype(str)
val_data['encoded_label'] = val_data['encoded_label'].astype(str)

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=False,
    brightness_range=[0.6, 1.4],
    fill_mode="nearest"
)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# 7. Create generator function again
def create_generator(datagen, dataframe, batch_size=32, target_size=(128, 128), shuffle=True):
    return datagen.flow_from_dataframe(
        dataframe=dataframe,
        x_col='file_path',
        y_col='encoded_label',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='sparse',
        validate_filenames=True,
        shuffle=shuffle
    )

# 8. Recreate generators
train_generator = create_generator(train_datagen, train_data, shuffle=True)
val_generator = create_generator(val_datagen, val_data, shuffle=False)
# Out:
# Found 0 validated image filenames belonging to 0 classes.
# Found 0 validated image filenames belonging to 0 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/preprocessing/image.py:920: UserWarning: Found 6720 invalid image filename(s) in x_col="file_path". These filename(s) will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/preprocessing/image.py:920: UserWarning: Found 1680 invalid image filename(s) in x_col="file_path". These filename(s) will be ignored.
#   warnings.warn(

# %%
# 1. Import Necessary Libraries
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# Explanation:
# - pandas and numpy: for data manipulation
# - sklearn: for splitting data and encoding labels
# - tensorflow.keras: for building and training the neural network

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Unzip Dataset
# !unzip "/content/drive/My Drive/bttai-ajl-2025.zip" -d "/content/dataset"

# 3. Load Data
train_df = pd.read_csv('/content/dataset/train.csv')
test_df = pd.read_csv('/content/dataset/test.csv')

# 4. Add .jpg extension to md5hash column
train_df['md5hash'] = train_df['md5hash'].astype(str) + '.jpg'
test_df['md5hash'] = test_df['md5hash'].astype(str) + '.jpg'

# 5. Create file paths
train_df['file_path'] = '/content/dataset/train/train/' + train_df['label'] + '/' + train_df['md5hash']
test_df['file_path'] = '/content/dataset/test/test/' + test_df['md5hash']
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/My Drive/bttai-ajl-2025.zip
#   inflating: /content/dataset/sample_submission.csv
#   inflating: /content/dataset/test.csv
#   inflating: /content/dataset/test/test/000e8dd5ee75dd6668e978e7a4e6fe54.jpg
#   inflating: /content/dataset/test/test/0097275da3cb707415d13d2c59cf8c8c.jpg
#   inflating: /content/dataset/test/test/009c75339a21bb84a6425be6a95938d6.jpg
#   inflating: /content/dataset/test/test/016abe4884715af85cd3f309f93b9641.jpg
#   inflating: /content/dataset/test/test/018504389f4fa566232eb6e3ff838cb8.jpg
#   inflating: /content/dataset/test/test/01ba602def4506d8bfd5900cccd2ab4d.jpg
#   inflating: /content/dataset/test/test/024a737cf57eda5493e8cb30551b4e97.jpg
#   inflating: /content/dataset/test/test/0325ba9f88358e11a6abc3a63e584bf6.jpg
#   inflating: /content/dataset/test/test/032a4ac5c1a3a8a90f6e7aede2d1ab64.jpg
#   inflating: /content/dataset/test/test/0353409eed089c8165db5a968cf2c43f.jpg
#   inflating: /content/dataset/test/test/038e343e66d76cb93438f5460dbf4eeb.jpg
#   inflating: /content/dataset/test/test/0393b043e435e566657cf7d61879026c.jpg
#   inflating: /content/dataset/test/test/03c5124f5b1ccaf03bbc3fecc0249e6c.jpg
#   inflating: /content/dataset/test/test/0413727ba8089031523f7028d24a64da.jpg
#   inflating: /content/dataset/test/test/045a04ebe8c8153226ed22c27ba8fac3.jpg
#   inflating: /content/dataset/test/test/04672ea146d9dbc081cf63c160c7dfa0.jpg
#   inflating: /content/dataset/test/test/051e5c8ce730d6a81961ca551c9fdb2a.jpg
#   inflating: /content/dataset/test/test/0538c14b1dbc98e893372d3e132dfdbe.jpg
#   inflating: /content/dataset/test/test/0552f0ffd7f1125b7cdf8e44bdbfc0c6.jpg
#   inflating: /content/dataset/test/test/05eae8b3cf51683f62e9dcedd403c9ac.jpg
#   inflating: /content/dataset/test/test/05f2225244026969ba7435f5959acedf.jpg
#   inflating: /content/dataset/test/test/0639e79ac41e8de5cceee9f84b729b0e.jpg
#   inflating: /content/dataset/test/test/064f39810e82e6097f9c187f003ede0a.jpg
#   inflating: /content/dataset/test/test/06c312978164d6cc204751b5d7bea2f8.jpg
#   inflating: /content/dataset/test/test/06c7baa22fc3647a98fc8fe2e2985a77.jpg
#   inflating: /content/dataset/test/test/06fce53b79b05c19c2d2c8114f280fd1.jpg
#   inflating: /content/dataset/test/test/072015e0341f732ffa1f553d2a244515.jpg
#   inflating: /content/dataset/test/test/074d596348f9974d5fde86afa06fa605.jpg
#   inflating: /content/dataset/test/test/074e696e6cdf066eabf5b68d957487c9.jpg
#   inflating: /content/dataset/test/test/07a62c58c366377b9692b688e04d4f76.jpg
#   inflating: /content/dataset/test/test/07bbb2e37d5e4febf70890df43c9fbd6.jpg
#   inflating: /content/dataset/test/test/08447c464a1134284f6e267a3dffdf6f.jpg
#   inflating: /content/dataset/test/test/0844ae634f0e6e7ef1f73c2aeecbae0e.jpg
#   inflating: /content/dataset/test/test/0845ab554de878a73549aedc9dea3ce3.jpg
#   inflating: /content/dataset/test/test/084ee8ab04399c98bf9af20974c8dae8.jpg
#   inflating: /content/dataset/test/test/087315906369dd994456a197e0cac342.jpg
#   inflating: /content/dataset/test/test/08c31b995b51e21dcb10fb8d900bbaa2.jpg
#   inflating: /content/dataset/test/test/09890e72772d3ca35764342f06c15281.jpg
#   inflating: /content/dataset/test/test/098d28da6fe1db559126d701d74fc8e0.jpg
#   inflating: /content/dataset/test/test/09bdee78c82c4276a2f273180f66f751.jpg
#   inflating: /content/dataset/test/test/0a152642bc8270880808ab9477846866.jpg
#   inflating: /content/dataset/test/test/0a38a43963c4cceca1dfb8c998d83a71.jpg
#   inflating: /content/dataset/test/test/0a973eee9d131c3faabc62eb81f07bab.jpg
#   inflating: /content/dataset/test/test/0ac87111c95a35bccf902556b5d56f56.jpg
#   inflating: /content/dataset/test/test/0ad35686cc836776ddb21346413d273e.jpg
#   inflating: /content/dataset/test/test/0ae2c4aa7b6a3a133879f405331e9ebd.jpg
#   inflating: /content/dataset/test/test/0afbf2ec3f745735dc677ca739055838.jpg
#   inflating: /content/dataset/test/test/0b008499a165d7d0b5fd92218a7af035.jpg
#   inflating: /content/dataset/test/test/0b37a8a2da16fe77dde52ce6c2e9bb9b.jpg
#   inflating: /content/dataset/test/test/0b9c906977a5d2a78d7fa64004ccd6be.jpg
#   inflating: /content/dataset/test/test/0baf926f3983cc51160208c3af29106c.jpg
#   inflating: /content/dataset/test/test/0bb99b2f270898d179c9fba809e15b41.jpg
#   inflating: /content/dataset/test/test/0bd2ab66f36e69352a45d5122f4aad07.jpg
#   inflating: /content/dataset/test/test/0c0700fc7177d09e2df0c6658288cf8f.jpg
#   inflating: /content/dataset/test/test/0c3e253bc97c4b2402a61bcf693f3848.jpg
#   inflating: /content/dataset/test/test/0c6948c84593c37b5061d8ead8d8e6b1.jpg
#   inflating: /content/dataset/test/test/0ca7391635dab0884c85a1d929e723aa.jpg
#   inflating: /content/dataset/test/test/0ce4fc42fc7e5b0af7d17cdebbe18ee2.jpg
#   inflating: /content/dataset/test/test/0d03469c269b09952112b8d1990257cf.jpg
#   inflating: /content/dataset/test/test/0d1eb56fcd67699b9d277c7c0b3f8a1d.jpg
#   inflating: /content/dataset/test/test/0d240e7e0263db3d01450e39cecdb4cc.jpg
#   inflating: /content/dataset/test/test/0d9b3b69f19baf1b3db887dfbacafb26.jpg
#   inflating: /content/dataset/test/test/0e53f04b270579940142d00c6165f0a5.jpg
#   inflating: /content/dataset/test/test/0e55b54825db2d67edecfe12d01144a6.jpg
#   inflating: /content/dataset/test/test/0e72ba059329555ffcfe32d627a15b7a.jpg
#   inflating: /content/dataset/test/test/0ec3ad42fa779284c90cf3eafd31a6e7.jpg
#   inflating: /content/dataset/test/test/0ee34d8cc387db6430bba2d2ce793ac9.jpg
#   inflating: /content/dataset/test/test/0ef52360bce4b5cd6e44eab70175d53c.jpg
#   inflating: /content/dataset/test/test/0f5dc1d7b8e73e0b2df7bd1da6039dd0.jpg
#   inflating: /content/dataset/test/test/0f9899775f4ce2efa31ae2704361db38.jpg
#   inflating: /content/dataset/test/test/0f9a80fc4b30ce96e2440e1a67cd31d2.jpg
#   inflating: /content/dataset/test/test/0fb5b28ae94cfbebfe16209c00fb5a80.jpg
#   inflating: /content/dataset/test/test/0fd4f7d195dd7b1355d2389d8b2ed1dc.jpg
#   inflating: /content/dataset/test/test/106fc517df8d5e649afa9f6e64165776.jpg
#   inflating: /content/dataset/test/test/1093510b8b4e09034d87fb69cb047259.jpg
#   inflating: /content/dataset/test/test/10cacf2e0873ae8f01f0f13202545ff7.jpg
#   inflating: /content/dataset/test/test/10cbd07a7f2e658a27f31eac2ae17269.jpg
#   inflating: /content/dataset/test/test/118004ae04d7c04a7abb96c38483b6b0.jpg
#   inflating: /content/dataset/test/test/1186bc81d691487a953153cc0818a28c.jpg
#   inflating: /content/dataset/test/test/11bad1ca50668e9a7d6aee6b69d3bc47.jpg
#   inflating: /content/dataset/test/test/11c8d1839a362fdb5e02150d0421c1a4.jpg
#   inflating: /content/dataset/test/test/11f45cfda08e482b02f52701a461e4aa.jpg
#   inflating: /content/dataset/test/test/12056f489798de5eb80a7d07dde875df.jpg
#   inflating: /content/dataset/test/test/1225748569e2495256edb1f615dab952.jpg
#   inflating: /content/dataset/test/test/127c095dd4daf67da813ea08e0a814c9.jpg
#   inflating: /content/dataset/test/test/12aff52bef4cb6d836dbb03ffb578817.jpg
#   inflating: /content/dataset/test/test/12cfaf761e615d962029682f838f3c83.jpg
#   inflating: /content/dataset/test/test/13135f44ed77ea527b70db862a83bd61.jpg
#   inflating: /content/dataset/test/test/132fe9a3f576acc03bfd96ccd4b43783.jpg
#   inflating: /content/dataset/test/test/13aa2de8804ae601cd45c1c4cac9bc6f.jpg
#   inflating: /content/dataset/test/test/13aa381871e7b7acd8bd340db1e99e45.jpg
#   inflating: /content/dataset/test/test/13e27cd3114abb74f2321ee34e5417ba.jpg
#   inflating: /content/dataset/test/test/1400a56e8de2b64427acf3ba96895ded.jpg
#   inflating: /content/dataset/test/test/142cf402ecda22abae480a3866444796.jpg
#   inflating: /content/dataset/test/test/145e13a479f0c026fcb0630d2f9d47b8.jpg
#   inflating: /content/dataset/test/test/14d2333c46a7f94b0b64c6ed0547dd75.jpg
#   inflating: /content/dataset/test/test/1511867bba2a64f76dc383184e0e92b0.jpg
#   inflating: /content/dataset/test/test/151d0a85fa73fc70f69233abfd00e6f9.jpg
#   inflating: /content/dataset/test/test/155d6961a4ba33aac316c0ed099690fe.jpg
#   inflating: /content/dataset/test/test/1579e85ffbc506c10a9c44e58f23227e.jpg
#   inflating: /content/dataset/test/test/158b595ac3b57ae843eadbb63636c3ba.jpg
#   inflating: /content/dataset/test/test/15a259f7d6ba10129c0cc837d551a5b8.jpg
#   inflating: /content/dataset/test/test/15e4e61777fdee377d7a930c224939d0.jpg
#   inflating: /content/dataset/test/test/15ed87fbe8626bffb60e599d3aedb104.jpg
#   inflating: /content/dataset/test/test/15faf965b2b5b13bab84ca28d04ba20c.jpg
#   inflating: /content/dataset/test/test/160dbc3e65bc20f7fa82f27bcd79d60c.jpg
#   inflating: /content/dataset/test/test/1616459eaaa8f79463b01fd100f419bf.jpg
#   inflating: /content/dataset/test/test/161b47d35bcc8a3a6e5f57a88f2a233c.jpg
#   inflating: /content/dataset/test/test/163d9c550fad4704990a3d1b8183d0f8.jpg
#   inflating: /content/dataset/test/test/1663e75536f056d5158dcd192e591b1e.jpg
#   inflating: /content/dataset/test/test/1681c65312e7c67fcec67b39a5f31162.jpg
#   inflating: /content/dataset/test/test/1695bd10a336ec55c2ef289b51b8b43a.jpg
#   inflating: /content/dataset/test/test/16c089e04436faa844be84aba9d0179a.jpg
#   inflating: /content/dataset/test/test/16d1e6b4143c88cb158a50ea8bc3a595.jpg
#   inflating: /content/dataset/test/test/16eec7d9deedb55eb2e71f70aa1f0319.jpg
#   inflating: /content/dataset/test/test/174f6d759798e3fec307a2b7b513f139.jpg
#   inflating: /content/dataset/test/test/17671141fadfbc7d358a5e2cc4b98b58.jpg
#   inflating: /content/dataset/test/test/176892dfc10eabf4ad8b1f50ec5df7e5.jpg
#   inflating: /content/dataset/test/test/17d220d256211aeff23230af4f1bc977.jpg
#   inflating: /content/dataset/test/test/184d4c82d2d715ccc299db11357ea24c.jpg
#   inflating: /content/dataset/test/test/185ae0e5acbb25166758dc72e385d3aa.jpg
#   inflating: /content/dataset/test/test/190822f2e75490299428db99d2f34486.jpg
#   inflating: /content/dataset/test/test/192c8a174e6f594b44cdd00dd9f73d44.jpg
#   inflating: /content/dataset/test/test/1997f41adb38d92f1f3c60a0f75dbd11.jpg
#   inflating: /content/dataset/test/test/19e7cad902144cb742b342bb82b395eb.jpg
#   inflating: /content/dataset/test/test/1a0045ce41534142bd6aa55b22bc4a91.jpg
#   inflating: /content/dataset/test/test/1a0c9c273d706d38e5a25149e0a37971.jpg
#   inflating: /content/dataset/test/test/1a4fdeead0b5690e36ea85c57e1e87c5.jpg
#   inflating: /content/dataset/test/test/1a78edee88e9af57b3f2be343fe14d85.jpg
#   inflating: /content/dataset/test/test/1a7f5be93d32df0863ffa3115bdd1a63.jpg
#   inflating: /content/dataset/test/test/1a9e904ebc92a8322d12a24a79b02b61.jpg
#   inflating: /content/dataset/test/test/1ac5d3755f3e4e77ee6d100dfc333d6d.jpg
#   inflating: /content/dataset/test/test/1acfdf44aa359551366c7e352ef9e7c8.jpg
#   inflating: /content/dataset/test/test/1aec33dc780057f576a8064deffe9cc8.jpg
#   inflating: /content/dataset/test/test/1af9eb6b01aea02e6459d942c20f3f98.jpg
#   inflating: /content/dataset/test/test/1b223dc98a9d6e38cc2a6564658c222f.jpg
#   inflating: /content/dataset/test/test/1bbe4519608f606a18adf1811fd1c051.jpg
#   inflating: /content/dataset/test/test/1bd0b39996792be32b7ed241117f121d.jpg
#   inflating: /content/dataset/test/test/1bf91a83418fa163a455269a08aa1d86.jpg
#   inflating: /content/dataset/test/test/1c5adfdbc1c9bda0bc57c328a0ed4b35.jpg
#   inflating: /content/dataset/test/test/1ca7a0d873e3ebdfbdbe0e22c4d5d485.jpg
#   inflating: /content/dataset/test/test/1cc5a0ffcaf2f370cd65f10eeeb7fddd.jpg
#   inflating: /content/dataset/test/test/1d07e0f2fc08af46884dff93e34d797a.jpg
#   inflating: /content/dataset/test/test/1d5fec5379a83b91079dcc0721ba7a11.jpg
#   inflating: /content/dataset/test/test/1d78d91cb196cb45b40c615cbf7a94ff.jpg
#   inflating: /content/dataset/test/test/1d87ddf86f42c4febe29c9b5efcda416.jpg
#   inflating: /content/dataset/test/test/1d8fcc49e4dda6868fcf76916fc14405.jpg
#   inflating: /content/dataset/test/test/1e05b3cfccbf7b4143f709a9423fcea5.jpg
#   inflating: /content/dataset/test/test/1e55e67f3e9e3c739cb50534f15f1b8d.jpg
#   inflating: /content/dataset/test/test/1e7821b3692bc364a566152c7cb84507.jpg
#   inflating: /content/dataset/test/test/1e7e94a57dba71d805e9ca59ffc99758.jpg
#   inflating: /content/dataset/test/test/1e88430bd7f6efcb4d7c77d1c541a186.jpg
#   inflating: /content/dataset/test/test/1ed53774dfae21b81495cab1d16f1149.jpg
#   inflating: /content/dataset/test/test/1f00d2c15eaae750c70f5b93035a5c0c.jpg
#   inflating: /content/dataset/test/test/1f0af24c77f720c6c009b0aaae30c3ea.jpg
#   inflating: /content/dataset/test/test/1f12c62df49fd29ed0ded41bd028e82e.jpg
#   inflating: /content/dataset/test/test/1ff28481af19f530c70721fafe2decc0.jpg
#   inflating: /content/dataset/test/test/2004c88f0aba56122257c4f71e67c719.jpg
#   inflating: /content/dataset/test/test/20135a88216aad60c409dc97dde06e73.jpg
#   inflating: /content/dataset/test/test/2017a2789790c2ae724917624752ae5e.jpg
#   inflating: /content/dataset/test/test/204f57f5c4dd76c0841f106da6993d53.jpg
#   inflating: /content/dataset/test/test/20fa1e49372b9f495b9d7117f4f2d3bc.jpg
#   inflating: /content/dataset/test/test/2108592fb9106e94dc7dc89f16f40c03.jpg
#   inflating: /content/dataset/test/test/21b4c6bf65333cf88875d6d73761673f.jpg
#   inflating: /content/dataset/test/test/220dec60e4841b303a359de5b249af6c.jpg
#   inflating: /content/dataset/test/test/221cdcf36bafd8203b9a9c0751e08154.jpg
#   inflating: /content/dataset/test/test/22453eeab8eb57c76951e23e713ecfdf.jpg
#   inflating: /content/dataset/test/test/22517077a92297c9c87dced4121b1e00.jpg
#   inflating: /content/dataset/test/test/226e024f7a2e67c70cd8e51fdd4edf33.jpg
#   inflating: /content/dataset/test/test/227aabac4aa7eca8fa4b9fb2abddc5a0.jpg
#   inflating: /content/dataset/test/test/228205232185bed356ba1aafe35b41ac.jpg
#   inflating: /content/dataset/test/test/22bcca7d579abf5c2c121c98aa01a4c7.jpg
#   inflating: /content/dataset/test/test/22d5b9ebf533411edc7d868d5559d0c1.jpg
#   inflating: /content/dataset/test/test/22ecdf81668c637355d9020d35e2ae0b.jpg
#   inflating: /content/dataset/test/test/2331c9221825472c0a643dcc3a1f5249.jpg
#   inflating: /content/dataset/test/test/23ca4d83dffa92d9a222b70d803c499c.jpg
#   inflating: /content/dataset/test/test/23f8b15973a621ced1807768301eabaf.jpg
#   inflating: /content/dataset/test/test/2426c7f42fe341ffba88b82e2108a81e.jpg
#   inflating: /content/dataset/test/test/2427f4ddad999d44139aa8b91e937885.jpg
#   inflating: /content/dataset/test/test/2475581bf40d111f31146165fce3441b.jpg
#   inflating: /content/dataset/test/test/2517732be7bf3296d8da4eabb58d1e59.jpg
#   inflating: /content/dataset/test/test/2526f45c72e51e324cc70a56faa9616a.jpg
#   inflating: /content/dataset/test/test/25d6287a7029492939284f43d0a626b0.jpg
#   inflating: /content/dataset/test/test/263fff0e6333059361ea79dc15c6c6a4.jpg
#   inflating: /content/dataset/test/test/26628fb7dc4341b5ac2ef37525925fe0.jpg
#   inflating: /content/dataset/test/test/268e737f44bce5f54b4bcee52baf7e66.jpg
#   inflating: /content/dataset/test/test/269712d911c7baf3c2e41d88c5845851.jpg
#   inflating: /content/dataset/test/test/26ca1663d0d35255aa471578fd030131.jpg
#   inflating: /content/dataset/test/test/270a217e6e961cf405a4ad46a110ff69.jpg
#   inflating: /content/dataset/test/test/27636e10ca656290c8dfc9b238bf5a17.jpg
#   inflating: /content/dataset/test/test/27b90df80041990f4aa15c5d0b1c5746.jpg
#   inflating: /content/dataset/test/test/27fa5ac58bd8c5a693e8e0bd0bbe6f39.jpg
#   inflating: /content/dataset/test/test/281be8ea8723dba5c6a0ab7e3e257d8d.jpg
#   inflating: /content/dataset/test/test/28209338ca3b7687ebd8a4bf7da3a5a0.jpg
#   inflating: /content/dataset/test/test/2861f208db32e09e3841ead44f577ddb.jpg
#   inflating: /content/dataset/test/test/291bfda376c0ac532fb791d22ae1bb80.jpg
#   inflating: /content/dataset/test/test/296ec4776e89a65ce8e262ed545ed4bb.jpg
#   inflating: /content/dataset/test/test/298fc8e9382bcdd2668c98e710a3808e.jpg
#   inflating: /content/dataset/test/test/29bb3a16598d5e59c8d065c44ab3fba2.jpg
#   inflating: /content/dataset/test/test/29cc6dbc600fb5861d5de1cd057bcae7.jpg
#   inflating: /content/dataset/test/test/2a2b8a3357e28cdb445ca00168843970.jpg
#   inflating: /content/dataset/test/test/2a5ade59d80877fcfc12811abe61556e.jpg
#   inflating: /content/dataset/test/test/2aa5dac8b5f87535800796c039a818c8.jpg
#   inflating: /content/dataset/test/test/2bad4c856e10e29dcb76b7e1ad11ec51.jpg
#   inflating: /content/dataset/test/test/2bca2886bd9092632698662c969e551d.jpg
#   inflating: /content/dataset/test/test/2be140422a9716b494b20701f95ce039.jpg
#   inflating: /content/dataset/test/test/2c15d58bb14b91318e30abc20230d7eb.jpg
#   inflating: /content/dataset/test/test/2c658f5384d52f4c0943335694b10fc0.jpg
#   inflating: /content/dataset/test/test/2c70b85effc762d7b6a4bfc7746ef97b.jpg
#   inflating: /content/dataset/test/test/2cd328777af9ee59c90b18bec2be72e3.jpg
#   inflating: /content/dataset/test/test/2d344b03816a60495078387cc99f335d.jpg
#   inflating: /content/dataset/test/test/2d49855dfa4ecb5ce88095c78bbfe5c8.jpg
#   inflating: /content/dataset/test/test/2d6abc80650978d36907bda0009c88e2.jpg
#   inflating: /content/dataset/test/test/2d937eacdf1f2480a9266e029a667494.jpg
#   inflating: /content/dataset/test/test/2dbf863f60d92fcb6bd2cb08ab04abba.jpg
#   inflating: /content/dataset/test/test/2dc5c700e1ba2c10091d84c7c8818a7a.jpg
#   inflating: /content/dataset/test/test/2e3a440729e7c6dc0543b21895324b18.jpg
#   inflating: /content/dataset/test/test/2e8d80b36e871b1ff2b0b9ef8c8532f8.jpg
#   inflating: /content/dataset/test/test/2e9026dc8e4b4256aaad236b808de767.jpg
#   inflating: /content/dataset/test/test/2e9a44d7373e97c682c937249b38d622.jpg
#   inflating: /content/dataset/test/test/2ecf3527cc84f9669aaa132a1662a5c1.jpg
#   inflating: /content/dataset/test/test/2edb9f6c4bd9f045320806d7c18f68a7.jpg
#   inflating: /content/dataset/test/test/2fdb31f6c3f6fc50b96f6607510cc263.jpg
#   inflating: /content/dataset/test/test/304fad9f2fda262980d7964322a43e00.jpg
#   inflating: /content/dataset/test/test/306fb95786c67996e75296b97c2c0473.jpg
#   inflating: /content/dataset/test/test/30b6c1170e08b3e8b97c080a8e67ada7.jpg
#   inflating: /content/dataset/test/test/30bd180288eedd15b8aad8acb7ed91da.jpg
#   inflating: /content/dataset/test/test/30e6f943452facf1ffbed708e645f4b8.jpg
#   inflating: /content/dataset/test/test/31301723ac2727fd70f511a86ceb089c.jpg
#   inflating: /content/dataset/test/test/3148e06be77894f760bf482fe7e6f2e5.jpg
#   inflating: /content/dataset/test/test/315ed43d1da403041e34b016bac90381.jpg
#   inflating: /content/dataset/test/test/318c8e5f64892f91b7a0e093457d90b4.jpg
#   inflating: /content/dataset/test/test/31c42f79bb918fe1d8ef35b553e7d8cf.jpg
#   inflating: /content/dataset/test/test/31e6979966293854a7feec28eca58f6e.jpg
#   inflating: /content/dataset/test/test/31eee568029f5a70bbda34af551bc67b.jpg
#   inflating: /content/dataset/test/test/3217ba36e80b39e457245877a77349d8.jpg
#   inflating: /content/dataset/test/test/329d3223fddeadbf5a62cff7b28a2d17.jpg
#   inflating: /content/dataset/test/test/32d9c78ee47a1d657769da9648857b38.jpg
#   inflating: /content/dataset/test/test/32dc52b5114e1aac6dab9fca50a6746a.jpg
#   inflating: /content/dataset/test/test/330f594ff345fbdd5b58ed187003b067.jpg
#   inflating: /content/dataset/test/test/3310c8f8bb1c974cbf1a3e33969ef039.jpg
#   inflating: /content/dataset/test/test/33184eb4424abaf46843d89c4c408552.jpg
#   inflating: /content/dataset/test/test/3368f86f3ab52a1362f4c1aac02c14be.jpg
#   inflating: /content/dataset/test/test/338772cc570ce83a7cca87638bcbc40b.jpg
#   inflating: /content/dataset/test/test/33ad4f24bc2f4e0fff7ffc8cab93cb05.jpg
#   inflating: /content/dataset/test/test/33b93a3dabdd6249159f5f3b1661f218.jpg
#   inflating: /content/dataset/test/test/33f6ba9badcccedc1238ae3c14c336ba.jpg
#   inflating: /content/dataset/test/test/33f9dfe5e1a2e7b6ce4c32f3cc889930.jpg
#   inflating: /content/dataset/test/test/3439269c515260af7ce8530c7f1c693a.jpg
#   inflating: /content/dataset/test/test/3463d25c4b8bc5061a3faa4ca6715537.jpg
#   inflating: /content/dataset/test/test/3493941ada3b6fdc44f3546b22f20d50.jpg
#   inflating: /content/dataset/test/test/34a4c651410d5aba949d1f62b8cdd1cd.jpg
#   inflating: /content/dataset/test/test/34ca72684487fafccfe617f7294d6938.jpg
#   inflating: /content/dataset/test/test/364bf519149491d77d15929901e92741.jpg
#   inflating: /content/dataset/test/test/366f3497de9c6d68d7e3c684d5d8c1ad.jpg
#   inflating: /content/dataset/test/test/36c7bbdced601b5d9fb1cc7cdc0df7e3.jpg
#   inflating: /content/dataset/test/test/3741b8a8ff7b38da7204810ead3aba9f.jpg
#   inflating: /content/dataset/test/test/37566d4150bbc6080c2dd4ecc7ff9431.jpg
#   inflating: /content/dataset/test/test/3791b30f96733f69b473c8d2fcf3998b.jpg
#   inflating: /content/dataset/test/test/3826e75f78b423e266c2dafc1b9809a9.jpg
#   inflating: /content/dataset/test/test/3834f2b1138b376486087b355da6dbad.jpg
#   inflating: /content/dataset/test/test/3887855c8303e3c019d89f384140a9f9.jpg
#   inflating: /content/dataset/test/test/3889e119deceb3e9f6b0719ad9431086.jpg
#   inflating: /content/dataset/test/test/38b649997c117ffa68e7319ea9f111e6.jpg
#   inflating: /content/dataset/test/test/3900f18cf0b25ba086d55615155482a8.jpg
#   inflating: /content/dataset/test/test/3988959d950efaef1651fe12b8d8bf7b.jpg
#   inflating: /content/dataset/test/test/39b1853bbd7aee8beb2bd4be5bf0f922.jpg
#   inflating: /content/dataset/test/test/39bef78824cddba30883954d4f12c6e0.jpg
#   inflating: /content/dataset/test/test/39caa210f24486000791251976b55f08.jpg
#   inflating: /content/dataset/test/test/39d7a3160a81e3ee93b2408a371d6510.jpg
#   inflating: /content/dataset/test/test/39f3448f33a429935cf1601f1585bd12.jpg
#   inflating: /content/dataset/test/test/3a1705edde2e27f35e7472eb76755bec.jpg
#   inflating: /content/dataset/test/test/3a5d464ccdb5cd8feee8424daf1b9758.jpg
#   inflating: /content/dataset/test/test/3a6a24ba22604e37a8fc8e5c7dfb0b4c.jpg
#   inflating: /content/dataset/test/test/3a99a5259471f5fee1d4db0d2067b413.jpg
#   inflating: /content/dataset/test/test/3b11265aff44e939cd045b9e5f3a0045.jpg
#   inflating: /content/dataset/test/test/3b290d262098f761d719aa07cf36c040.jpg
#   inflating: /content/dataset/test/test/3b3da93bdb3448afd0570afea24eae41.jpg
#   inflating: /content/dataset/test/test/3b4eb993fa2701b6da14952ad535d038.jpg
#   inflating: /content/dataset/test/test/3b7e06dda645a02dca6abfc20a02c4b5.jpg
#   inflating: /content/dataset/test/test/3b843066b041e22f335a890eae042b2a.jpg
#   inflating: /content/dataset/test/test/3bc997188f8c7966cebd6e6d92eca463.jpg
#   inflating: /content/dataset/test/test/3be7f195269f4cb0a7d2528223971f44.jpg
#   inflating: /content/dataset/test/test/3c066c1414b59ef40046a836a0b905e5.jpg
#   inflating: /content/dataset/test/test/3c248f623e262cadd1a608642df1934b.jpg
#   inflating: /content/dataset/test/test/3c4903173b7b1a7c309a1af110685216.jpg
#   inflating: /content/dataset/test/test/3c50f209d0d5c01b5bf6ac2e47059211.jpg
#   inflating: /content/dataset/test/test/3c8561db288ae7144a8e09b49121b132.jpg
#   inflating: /content/dataset/test/test/3c872d2410c57441eccd4368ece6f28a.jpg
#   inflating: /content/dataset/test/test/3c8898cea81673fe523d75dc4a4c0d2d.jpg
#   inflating: /content/dataset/test/test/3cece09559deee48b30b052851362994.jpg
#   inflating: /content/dataset/test/test/3d2f1d3763f8335375ab3f51cd2e00c5.jpg
#   inflating: /content/dataset/test/test/3d74745cdcd5f31b835d1ff21abc39b0.jpg
#   inflating: /content/dataset/test/test/3e01f243986c7b75c3ebe6fb66d0cab2.jpg
#   inflating: /content/dataset/test/test/3e0dd46a6a2d7dfd17bb444a3cf050c5.jpg
#   inflating: /content/dataset/test/test/3e6b4ab56597dce5f196f82b752c43b2.jpg
#   inflating: /content/dataset/test/test/3e9e422aca2163c9c46222bd6517432f.jpg
#   inflating: /content/dataset/test/test/3f014488acf61087ab152f8dc5fac8b3.jpg
#   inflating: /content/dataset/test/test/3f5585b2050389844a621e34f98dc191.jpg
#   inflating: /content/dataset/test/test/3f982d9ba541babca8b41d94ee6f4a0d.jpg
#   inflating: /content/dataset/test/test/400a5262ec66abc4d4a6a92dec155d87.jpg
#   inflating: /content/dataset/test/test/402f0c0b3da52105897eadd247cb100e.jpg
#   inflating: /content/dataset/test/test/4062f7d2bf4baa0f792741ceac66958f.jpg
#   inflating: /content/dataset/test/test/406cacfb22eaa42f6eda4bf27aa5b081.jpg
#   inflating: /content/dataset/test/test/409819704e132fbf1af7972247a61477.jpg
#   inflating: /content/dataset/test/test/40a1318214bb8de10ec2cd70ad71f859.jpg
#   inflating: /content/dataset/test/test/40a8a67e6d6ade17c43beb1d20dbef84.jpg
#   inflating: /content/dataset/test/test/40abd94119ad5fbeabd6ae00e30e31f7.jpg
#   inflating: /content/dataset/test/test/40b3e8829b08cfac1b06b44857e290f4.jpg
#   inflating: /content/dataset/test/test/40b9006b90679ab5560ebe3ce1a589a1.jpg
#   inflating: /content/dataset/test/test/411f9076f8cd3106153147b5f072b467.jpg
#   inflating: /content/dataset/test/test/413a896e96ee3c63962834b0e6498bd4.jpg
#   inflating: /content/dataset/test/test/4173d5a2337e044eaced6778c34be2ea.jpg
#   inflating: /content/dataset/test/test/418c81a23f78b4850106bae29332e97f.jpg
#   inflating: /content/dataset/test/test/418d009435bf224eef9a07097696a305.jpg
#   inflating: /content/dataset/test/test/41ad4baf7c3295c2ed44eba9da4c938e.jpg
#   inflating: /content/dataset/test/test/41dffc4224be2a0a9b2b31243755b1ae.jpg
#   inflating: /content/dataset/test/test/421307b71f4e267df9fdec5a5c91c67e.jpg
#   inflating: /content/dataset/test/test/4248fc4d507e6ebf3ddc136f1344b05c.jpg
#   inflating: /content/dataset/test/test/42b49544799141c6f402c6f7d1fd0cce.jpg
#   inflating: /content/dataset/test/test/42bb46cb779b95f10e531e2b6181e439.jpg
#   inflating: /content/dataset/test/test/42ca868d015f5b088e3bfbd28db1621f.jpg
#   inflating: /content/dataset/test/test/43262c5ed7d5c29f9547e40f5bcac4fd.jpg
#   inflating: /content/dataset/test/test/4343f98b39a54c43563b2819a20beaea.jpg
#   inflating: /content/dataset/test/test/43534ab689527642db737a5a6931993a.jpg
#   inflating: /content/dataset/test/test/435be3e0fb6848cf8418d56ce0ed9ef7.jpg
#   inflating: /content/dataset/test/test/43709a26cd70d509fcb12de796ddcc69.jpg
#   inflating: /content/dataset/test/test/437159c605260bdd079af230566af291.jpg
#   inflating: /content/dataset/test/test/43a5a3a84961dffd74413ae75d06532c.jpg
#   inflating: /content/dataset/test/test/442f91c9c99a3ba2b0ca25a1c381b28c.jpg
#   inflating: /content/dataset/test/test/444aaf9840087865c2705b1dd733a1d9.jpg
#   inflating: /content/dataset/test/test/447a8a8c93a59d870056b006dd14df26.jpg
#   inflating: /content/dataset/test/test/44aefdc6bc7f4bc1bbf66f960b6e1985.jpg
#   inflating: /content/dataset/test/test/44b0916f218f564db263ff46a009d212.jpg
#   inflating: /content/dataset/test/test/44bb284877cbebaeb393b2ed07606de5.jpg
#   inflating: /content/dataset/test/test/44db8ec026393a9fe950d286824bea30.jpg
#   inflating: /content/dataset/test/test/44df5dceb5722eeaac76f8957926ae0a.jpg
#   inflating: /content/dataset/test/test/45297051705ac6a8b8d04264cae21bc3.jpg
#   inflating: /content/dataset/test/test/4536ca109630631812769474f4cadcb6.jpg
#   inflating: /content/dataset/test/test/45f7fe0e10214e32e890cad9d29d4811.jpg
#   inflating: /content/dataset/test/test/45faa12ef71900861d9a6d3d448035f2.jpg
#   inflating: /content/dataset/test/test/466ad4e193a5c1ea266486037950ca91.jpg
#   inflating: /content/dataset/test/test/4670285632e1c288ec0ac64a15ef82af.jpg
#   inflating: /content/dataset/test/test/46e8e18c64c228c71550ae4f50a92036.jpg
#   inflating: /content/dataset/test/test/4735dff622753bd02c22a764a9281846.jpg
#   inflating: /content/dataset/test/test/473f3594b1a24ac3109f2ace980b2953.jpg
#   inflating: /content/dataset/test/test/47cb1bb512da0f22002f75e9f158c6e8.jpg
#   inflating: /content/dataset/test/test/47f82c73448a0cbf900d839ac3872496.jpg
#   inflating: /content/dataset/test/test/47fdee8c6edf33214c50371b27554356.jpg
#   inflating: /content/dataset/test/test/482f40d7e3d25795f61d53161d2d3f6f.jpg
#   inflating: /content/dataset/test/test/4874ae4360510673a0cbe6310a4acce0.jpg
#   inflating: /content/dataset/test/test/48a2d3c07db35f6232411a257e7a95e9.jpg
#   inflating: /content/dataset/test/test/48cd09dfa86f641cda0d413a486345fa.jpg
#   inflating: /content/dataset/test/test/48cec03c27c9107baa6cea045851ec23.jpg
#   inflating: /content/dataset/test/test/48cf483953e0275a096914b1723221c3.jpg
#   inflating: /content/dataset/test/test/493b84bf949c2556d88e1fd06f631115.jpg
#   inflating: /content/dataset/test/test/4981320ef16be15730f7fce6207c9f88.jpg
#   inflating: /content/dataset/test/test/49ed416e5f1dc646ecbaf99b23b48095.jpg
#   inflating: /content/dataset/test/test/49f285fcadfe1b9348502534acb19e4e.jpg
#   inflating: /content/dataset/test/test/4ab6234ead6b243165c53ad33b708d12.jpg
#   inflating: /content/dataset/test/test/4abcc083990e6408c7936f204a913a81.jpg
#   inflating: /content/dataset/test/test/4ac07b83e993297cb8ef4efa00212fce.jpg
#   inflating: /content/dataset/test/test/4b1f5f367ebc0d5207088d329d8eeee2.jpg
#   inflating: /content/dataset/test/test/4b3198562de3a684002fedc551a72c90.jpg
#   inflating: /content/dataset/test/test/4b6e28d38197e3e0ea167421dc6d21fb.jpg
#   inflating: /content/dataset/test/test/4ba7898548e5321a0f0c5a4a5317386b.jpg
#   inflating: /content/dataset/test/test/4bae18a5cf6f2f211389b5d97f3fe840.jpg
#   inflating: /content/dataset/test/test/4bda36c130bc5222cc928bde1ac19cdd.jpg
#   inflating: /content/dataset/test/test/4c13340c2a4e28252816d39fa018bbc8.jpg
#   inflating: /content/dataset/test/test/4c25a70e58e5bdcba90060add311bf10.jpg
#   inflating: /content/dataset/test/test/4c3f795cf8eb72b946f9bd2642cf23c1.jpg
#   inflating: /content/dataset/test/test/4c4ee394e3bd1da54bdec11874990b30.jpg
#   inflating: /content/dataset/test/test/4c57a9eec4b544ae4dae4a56a6d9f8cf.jpg
#   inflating: /content/dataset/test/test/4c60daad1f47500b7aa569e7e9c4fbeb.jpg
#   inflating: /content/dataset/test/test/4c6e412b4f3f5b743e7fbc2a2c535eef.jpg
#   inflating: /content/dataset/test/test/4cbd191d60f97a3b5a8d7b3ad5cc564c.jpg
#   inflating: /content/dataset/test/test/4cdf3362d0ed7447f98b1a44f0746ab4.jpg
#   inflating: /content/dataset/test/test/4d36657f6a39bec453c8e41acc40023f.jpg
#   inflating: /content/dataset/test/test/4d43d8ea8c6102ec7d6c66dcf0e78006.jpg
#   inflating: /content/dataset/test/test/4d6a5c8b2e73ea8acbcbae17a070f9df.jpg
#   inflating: /content/dataset/test/test/4da76fdfd312fd889a3e0d02b666dede.jpg
#   inflating: /content/dataset/test/test/4dc08af974e49708c2a572d40c44e1c6.jpg
#   inflating: /content/dataset/test/test/4de00b6c7214b5f74d8411fb3d523c0b.jpg
#   inflating: /content/dataset/test/test/4de99fdc6b65ce2148d412a39d112768.jpg
#   inflating: /content/dataset/test/test/4e1ba6883f1b236b2a4a5684ab50b7ae.jpg
#   inflating: /content/dataset/test/test/4e21b16f514f906132e7d55825c98117.jpg
#   inflating: /content/dataset/test/test/4e22f7ad0e178a67b08db1d11219a0a8.jpg
#   inflating: /content/dataset/test/test/4e28e2e586e563db2112ad1afa25fcf0.jpg
#   inflating: /content/dataset/test/test/4e63404b516800a93d6dc91e4f4a23b6.jpg
#   inflating: /content/dataset/test/test/4ee44e55d4ba975e0e3b5fa22a6f7ccf.jpg
#   inflating: /content/dataset/test/test/4eff46ba9c97e429dc688f530a4e5fbc.jpg
#   inflating: /content/dataset/test/test/4f1076e6080882564075e0c677ce4f1b.jpg
#   inflating: /content/dataset/test/test/4f61db9db37394caa8bd630568d77ad5.jpg
#   inflating: /content/dataset/test/test/4f87ef083363ca11a44080edc73b3568.jpg
#   inflating: /content/dataset/test/test/4ff1ea06e98ef27ae93b27fbfa384a75.jpg
#   inflating: /content/dataset/test/test/50153c30ba3b0205caad6f4281929dbf.jpg
#   inflating: /content/dataset/test/test/50203f0e1cc3ccf33cd2cbfdfd475c02.jpg
#   inflating: /content/dataset/test/test/5080e0d5806f34bec6b2055ec21a2583.jpg
#   inflating: /content/dataset/test/test/5083ac97bda2b5e9906746e2fe16179a.jpg
#   inflating: /content/dataset/test/test/50a5b3518678c84fed613629a0fefeb3.jpg
#   inflating: /content/dataset/test/test/50b4cc0d8dcf2b393bb80c89ef6d0196.jpg
#   inflating: /content/dataset/test/test/50c5fdef946e0cd8ef022a82c6167381.jpg
#   inflating: /content/dataset/test/test/50c825e6e56ab72f1ecde0328ff77277.jpg
#   inflating: /content/dataset/test/test/513f39489e5c4ff137116a7f063607d4.jpg
#   inflating: /content/dataset/test/test/514d66c5bfd013ff057365fcd5c995f2.jpg
#   inflating: /content/dataset/test/test/517c9627617ef9e5689e364ee5d88069.jpg
#   inflating: /content/dataset/test/test/518f1b72caa5718bb84cc769631656b3.jpg
#   inflating: /content/dataset/test/test/51b542089596a4d122839b333b656871.jpg
#   inflating: /content/dataset/test/test/51bc35ea07c27621b3abe3c1bf07a034.jpg
#   inflating: /content/dataset/test/test/51d2eb9781f05cf0663c78194e93792a.jpg
#   inflating: /content/dataset/test/test/51e0ca33acbfd85ac2910c698bb24ff1.jpg
#   inflating: /content/dataset/test/test/521773286f1d292e0cdcf5c1354fc0ea.jpg
#   inflating: /content/dataset/test/test/521bec867654c32d592f32f9256c5704.jpg
#   inflating: /content/dataset/test/test/52514f7abd18bb524279c10943916512.jpg
#   inflating: /content/dataset/test/test/52527e8d12636fd64523b3dcbeb94d57.jpg
#   inflating: /content/dataset/test/test/5271a8a3db4825d3fc5aad611b58bc9e.jpg
#   inflating: /content/dataset/test/test/52a99b2202af66856bb6a395e13a4e76.jpg
#   inflating: /content/dataset/test/test/52b87171653545584807c202b61fcbdd.jpg
#   inflating: /content/dataset/test/test/53320a2cc3e6c7188e040136a9dd6efb.jpg
#   inflating: /content/dataset/test/test/534efa4991400aa326f3ddadbe961225.jpg
#   inflating: /content/dataset/test/test/538c95f3f7cf85627092c7c1879caf5d.jpg
#   inflating: /content/dataset/test/test/53c015ad50dc837544c7718aa6a96166.jpg
#   inflating: /content/dataset/test/test/53f00019faad3f44c16652c4bad395ba.jpg
#   inflating: /content/dataset/test/test/5423e2d3ad68054e7b51e27e146fddca.jpg
#   inflating: /content/dataset/test/test/543017d891174b7fe9443a4dfa537410.jpg
#   inflating: /content/dataset/test/test/5456f68e2ad4417d213c0f7df0fab783.jpg
#   inflating: /content/dataset/test/test/5469148cef4a35a7d7c0f97cd2d0c345.jpg
#   inflating: /content/dataset/test/test/548ec840d0d93a2e469cd33f6127cd6d.jpg
#   inflating: /content/dataset/test/test/54aa2f1bf36b27de991db5cd358bde06.jpg
#   inflating: /content/dataset/test/test/54c7c26b914f17674a00a7355cdde37e.jpg
#   inflating: /content/dataset/test/test/54e31a5809f92d64232e1d9b37f11126.jpg
#   inflating: /content/dataset/test/test/54ea7e8da3eb7259216baaa66eecfcec.jpg
#   inflating: /content/dataset/test/test/550749c351ebf42acc3ec74f9f9a6de4.jpg
#   inflating: /content/dataset/test/test/558b6378ac18ecc0c35d6b33e073d1d2.jpg
#   inflating: /content/dataset/test/test/55d707c5de44c50878bbf408e9742033.jpg
#   inflating: /content/dataset/test/test/55e6df1b86dc62c4f5df159845193e17.jpg
#   inflating: /content/dataset/test/test/560d811d545a9fc209e18c944dce1ccd.jpg
#   inflating: /content/dataset/test/test/56c7427df79c37d0602a2797539ca761.jpg
#   inflating: /content/dataset/test/test/570bb039a6f13ce828d8a1551623a513.jpg
#   inflating: /content/dataset/test/test/574287cf077bf599f898cbdb64a5be44.jpg
#   inflating: /content/dataset/test/test/576d835921aceb16eea483aa84fc138a.jpg
#   inflating: /content/dataset/test/test/57aab823a0d448956ba9f1d82492a623.jpg
#   inflating: /content/dataset/test/test/58005ed792a5445438c7f32043d1818b.jpg
#   inflating: /content/dataset/test/test/584c4f9057c17656a36c862d527000a3.jpg
#   inflating: /content/dataset/test/test/58f4166ec79b9a80bb6a855cf0fd058a.jpg
#   inflating: /content/dataset/test/test/58f8a6ea4d65b0c235565a6f0dab1643.jpg
#   inflating: /content/dataset/test/test/5906081fcdc2eece8140e95a95f909f0.jpg
#   inflating: /content/dataset/test/test/591efe195b012d0413397ad1bf0bcfae.jpg
#   inflating: /content/dataset/test/test/59225534aff70594b39b620bfb21315a.jpg
#   inflating: /content/dataset/test/test/592d6879bebc0cf17a02f50dbc3dae83.jpg
#   inflating: /content/dataset/test/test/59c60187f6e65c32cbbadbdfc8b8df1d.jpg
#   inflating: /content/dataset/test/test/5a138952d0d9258bb0612a2e6ff5c36d.jpg
#   inflating: /content/dataset/test/test/5a18fc5a172112cbb0636b16d76078c5.jpg
#   inflating: /content/dataset/test/test/5a6480d3594d735eedf67a29281a1819.jpg
#   inflating: /content/dataset/test/test/5a7aa71b77edee5c2b60114edd6a2031.jpg
#   inflating: /content/dataset/test/test/5a7fda42a38599f347ae2e65dcf51879.jpg
#   inflating: /content/dataset/test/test/5b2d083698d7ed5b10d17f18714c3b54.jpg
#   inflating: /content/dataset/test/test/5b3fc65be3359e5ad8bbbb319c31596d.jpg
#   inflating: /content/dataset/test/test/5b552fb15839338227880aaac895128a.jpg
#   inflating: /content/dataset/test/test/5bec7b68c4b6e5c46953caf631a2cba8.jpg
#   inflating: /content/dataset/test/test/5bedb7aaeeeb002707f6118df00a564f.jpg
#   inflating: /content/dataset/test/test/5bfbbf980defc7097504589b63d5e330.jpg
#   inflating: /content/dataset/test/test/5c7a759d9b19417c828612dc9b016dc1.jpg
#   inflating: /content/dataset/test/test/5d07648c809dcaca09feef5c856ed3ed.jpg
#   inflating: /content/dataset/test/test/5d08b1474179bb4874416b01064b56ae.jpg
#   inflating: /content/dataset/test/test/5dc56924d6d68e2ee3d0dbc2abbab859.jpg
#   inflating: /content/dataset/test/test/5dcf89822b03a9620054dcddfb327cf5.jpg
#   inflating: /content/dataset/test/test/5dda143b37c12894ebbd9c196cd9d141.jpg
#   inflating: /content/dataset/test/test/5ebf2926c88d2a8b5411ae057705a5ac.jpg
#   inflating: /content/dataset/test/test/5f5834848e3b14da13ede7598b0d644b.jpg
#   inflating: /content/dataset/test/test/5f6bf606eaef0ac72ec1132558e8160a.jpg
#   inflating: /content/dataset/test/test/5f789231cfe92cef1737d0da94bfdad2.jpg
#   inflating: /content/dataset/test/test/5fa874b5fcba73713df72302a915df7c.jpg
#   inflating: /content/dataset/test/test/5ff2e2cbcbb9f92610ec54dca324d149.jpg
#   inflating: /content/dataset/test/test/5ffb0f37439ee5e465139feac2b33010.jpg
#   inflating: /content/dataset/test/test/5ffd8bfd72bf93492e07434924e9d15a.jpg
#   inflating: /content/dataset/test/test/600410cdc0fcd7be30fbf4f51f92b7cf.jpg
#   inflating: /content/dataset/test/test/600fa1053d015e9110a3ed7888e3c7d8.jpg
#   inflating: /content/dataset/test/test/608183886586661fbb2a422d4740c2e2.jpg
#   inflating: /content/dataset/test/test/60f79f88cbb999246aea835979d1c1db.jpg
#   inflating: /content/dataset/test/test/60f80cdf721287c40568fee2751bfc3e.jpg
#   inflating: /content/dataset/test/test/610238a9511e0242eac20a58568dff9b.jpg
#   inflating: /content/dataset/test/test/61687ac315e76923e2116ac2d20ebd33.jpg
#   inflating: /content/dataset/test/test/61be413c52eb1d7dad6a93d071f7d52e.jpg
#   inflating: /content/dataset/test/test/61c220d156f4c0cf2acdf5c8a9cc8ab1.jpg
#   inflating: /content/dataset/test/test/61d0e40071c675db6da228de6c04e292.jpg
#   inflating: /content/dataset/test/test/623760615181a0f95fd6d5419d62c797.jpg
#   inflating: /content/dataset/test/test/62711536b80f9a897c6d5bde4f320397.jpg
#   inflating: /content/dataset/test/test/6291ff38493700eccb9816dc3586cd17.jpg
#   inflating: /content/dataset/test/test/62c9e3126c690939ea356694a047d23b.jpg
#   inflating: /content/dataset/test/test/62d277784521ca0bc25d6e91268b3c71.jpg
#   inflating: /content/dataset/test/test/62eb1d002bfba0237bb37de8f4fc6536.jpg
#   inflating: /content/dataset/test/test/62f396f48e6501395d63b222cdc684d8.jpg
#   inflating: /content/dataset/test/test/62ff0258e565e9fa72d73f267221726c.jpg
#   inflating: /content/dataset/test/test/6323e7bf168cb3f170902b24cd05e8c4.jpg
#   inflating: /content/dataset/test/test/6353b7c1adbac3349984409728c756e3.jpg
#   inflating: /content/dataset/test/test/635cdb6a1cd94c714c8c393adb7c3ac1.jpg
#   inflating: /content/dataset/test/test/638cc168f86dcb834cf96af0a6d59f7e.jpg
#   inflating: /content/dataset/test/test/63b530d653923c1fa20cf2966cd689df.jpg
#   inflating: /content/dataset/test/test/63b6094e083862d617afe313c4aa9f1f.jpg
#   inflating: /content/dataset/test/test/6454800e31a16b2abc6c97fe3582faf3.jpg
#   inflating: /content/dataset/test/test/645a927c70a12b3ff6ce9667c5d56cc5.jpg
#   inflating: /content/dataset/test/test/6472c26e82d307a0929503604f91bcac.jpg
#   inflating: /content/dataset/test/test/648adc09de37624a92674d2b90d96188.jpg
#   inflating: /content/dataset/test/test/6494b1f8531d2213473a24f46a15d2ff.jpg
#   inflating: /content/dataset/test/test/64ba283eeed948b9af16855140ee78f6.jpg
#   inflating: /content/dataset/test/test/656c560e200b0cfca63346939fa848d3.jpg
#   inflating: /content/dataset/test/test/658446bde66c64e374d317e40fb40f91.jpg
#   inflating: /content/dataset/test/test/664d794014b44cfa24cd8c4c864be636.jpg
#   inflating: /content/dataset/test/test/66617b242abb82dcd77cf73970510afa.jpg
#   inflating: /content/dataset/test/test/66a4c312027be32485642a2d0232ac4a.jpg
#   inflating: /content/dataset/test/test/66f46297056511b1057d5c31ad7acd23.jpg
#   inflating: /content/dataset/test/test/673e2daccb06374f11b9bf5110fb9550.jpg
#   inflating: /content/dataset/test/test/675abb915f8549449ff6e68bb7d44879.jpg
#   inflating: /content/dataset/test/test/6762baef7e56c8d76869592b3054ce44.jpg
#   inflating: /content/dataset/test/test/67be5ded2639427a77761dbbcee1234c.jpg
#   inflating: /content/dataset/test/test/67f3fd31b44095d4a74fbe9a08f47ff2.jpg
#   inflating: /content/dataset/test/test/6822f9362f5560a53dfdf79fb77d48b4.jpg
#   inflating: /content/dataset/test/test/685207f1b77135e0fd5dfe6866bf658b.jpg
#   inflating: /content/dataset/test/test/686586ef815913c5cd197bcdb3718b5e.jpg
#   inflating: /content/dataset/test/test/688ac2ba9aff76f589c14be2813f9d5f.jpg
#   inflating: /content/dataset/test/test/689433a232b85e487ba0bf089792e374.jpg
#   inflating: /content/dataset/test/test/68c4093d23c19116b586d84b57c348ab.jpg
#   inflating: /content/dataset/test/test/68cd6c2474a38716c149a5e76d383703.jpg
#   inflating: /content/dataset/test/test/68daecb39b330760c4faddc47e842c77.jpg
#   inflating: /content/dataset/test/test/691260f9a6de48296c0bcd79084d1c24.jpg
#   inflating: /content/dataset/test/test/691e993248f5ba98fc7be6bede8dc9ac.jpg
#   inflating: /content/dataset/test/test/69425e7f864b9775266eca2c328fe766.jpg
#   inflating: /content/dataset/test/test/6946d50ada3bbfc10a3df8f5c0223b47.jpg
#   inflating: /content/dataset/test/test/69568fbb5f210c22cc07d54a578dfffe.jpg
#   inflating: /content/dataset/test/test/696922f3d6d65bfb880ba2636f96b1d2.jpg
#   inflating: /content/dataset/test/test/69b01fc8a537bc8c99ea976cc32bdc69.jpg
#   inflating: /content/dataset/test/test/69cfcc29d1376d77c9bcbfca301eefb6.jpg
#   inflating: /content/dataset/test/test/69ff175300cf6db570894f58aff1a957.jpg
#   inflating: /content/dataset/test/test/6a3640f5914cf269372e4e28f7df12c4.jpg
#   inflating: /content/dataset/test/test/6a42b572581dc870a1cfe3f15e7d5da8.jpg
#   inflating: /content/dataset/test/test/6afb94915e7935b5a4b0c1cee7bde806.jpg
#   inflating: /content/dataset/test/test/6b8443f997a29f08833996007cf7b10d.jpg
#   inflating: /content/dataset/test/test/6b868b0b74caec29ab51cc950d2179ea.jpg
#   inflating: /content/dataset/test/test/6bbb87c1ba24d5c658a393c19080c24f.jpg
#   inflating: /content/dataset/test/test/6bf57a76e354ce35747a5e1821ff40dc.jpg
#   inflating: /content/dataset/test/test/6c12f0e99a7af40789ae5aaf42946d84.jpg
#   inflating: /content/dataset/test/test/6c324c3f793408f1bbed60f75617c84d.jpg
#   inflating: /content/dataset/test/test/6c6d072123d56ce0ff132f48b5a17309.jpg
#   inflating: /content/dataset/test/test/6cae680fb52f29577297ee19ef5a142a.jpg
#   inflating: /content/dataset/test/test/6cdf26807d52792218193f5bce1a8567.jpg
#   inflating: /content/dataset/test/test/6cf10bfb15d43652310bd5ce509069a9.jpg
#   inflating: /content/dataset/test/test/6d2fb27bbaf2691ea85fa2ad7f334060.jpg
#   inflating: /content/dataset/test/test/6d9d3d6ab99f09c25d9c2042b303d167.jpg
#   inflating: /content/dataset/test/test/6dba48622336596a9576d587ce702142.jpg
#   inflating: /content/dataset/test/test/6dd41cfcffc748e96857d59341019284.jpg
#   inflating: /content/dataset/test/test/6e2da28f9169bd9f68f13afaa53f8500.jpg
#   inflating: /content/dataset/test/test/6e620c3a29ad45715a16799d26589be3.jpg
#   inflating: /content/dataset/test/test/6e7bfd02ac7b8fb2c8497250d6f7ce82.jpg
#   inflating: /content/dataset/test/test/6e9b03c88ecdc1885ad5f1b6586da01d.jpg
#   inflating: /content/dataset/test/test/6ed4688c517307e1da50129ece9da64d.jpg
#   inflating: /content/dataset/test/test/6ed995cc282c8d8ca9f2bdbcde554468.jpg
#   inflating: /content/dataset/test/test/6f197431cd2d540ed3c5c8c6a5296d54.jpg
#   inflating: /content/dataset/test/test/6f1cea03b7d8e82e852c1f95ee8a9d0f.jpg
#   inflating: /content/dataset/test/test/6f64857e9c143d28a6170bc774706814.jpg
#   inflating: /content/dataset/test/test/6f7e7323fc3b1d98c4e3bfe5273f6b92.jpg
#   inflating: /content/dataset/test/test/6f93aa757c0b91baceca396b7b76c90c.jpg
#   inflating: /content/dataset/test/test/6fa6459b12325e1c5ad7749b38dfdff0.jpg
#   inflating: /content/dataset/test/test/6fb6afb84ad3fadb641d9d5673156e93.jpg
#   inflating: /content/dataset/test/test/6fcd734b5541c09f54590f97183cb18e.jpg
#   inflating: /content/dataset/test/test/704c443b2f7d76de96f0ce1f260828d3.jpg
#   inflating: /content/dataset/test/test/705631921fe3d1cb05dcdcf9f48fe9a1.jpg
#   inflating: /content/dataset/test/test/7064467893a7e67d98d6e8f73957bf4e.jpg
#   inflating: /content/dataset/test/test/7075c2cde6d86aa53d709a2ead26b93f.jpg
#   inflating: /content/dataset/test/test/70a0b051fb01abcd5cdd01bf8b6aa5da.jpg
#   inflating: /content/dataset/test/test/70b99a1005a08821fd9b9c48d7e8e698.jpg
#   inflating: /content/dataset/test/test/70febe1909055262ca282551a222a10f.jpg
#   inflating: /content/dataset/test/test/711bc9852c2b8953647ec05bdf318c88.jpg
#   inflating: /content/dataset/test/test/717632d20df2589325f6769a45b0adc5.jpg
#   inflating: /content/dataset/test/test/71828e02c5def1b432fc028a764c7192.jpg
#   inflating: /content/dataset/test/test/71a101b8e494eb213b78a1274714de3b.jpg
#   inflating: /content/dataset/test/test/71a7b35ef0e804f4dac01d3119be6748.jpg
#   inflating: /content/dataset/test/test/71ce907aacb35c6da2b68996843c46b1.jpg
#   inflating: /content/dataset/test/test/71fc983e4c738a72a56725933d60edea.jpg
#   inflating: /content/dataset/test/test/7200dfb344d1c161b36c83598445e35d.jpg
#   inflating: /content/dataset/test/test/72714f4963e82e6d9b7b4f99a4f3b32e.jpg
#   inflating: /content/dataset/test/test/728a36e89f7599c7740a0935c8e36621.jpg
#   inflating: /content/dataset/test/test/72a404525b6a423e540759439b50b3da.jpg
#   inflating: /content/dataset/test/test/72aa410d76f560607fb2e74083b2e87d.jpg
#   inflating: /content/dataset/test/test/72b7bd69618ea149d63f3d41dc4ca287.jpg
#   inflating: /content/dataset/test/test/72bf4c07c8873dbf8d4b2c7ab5989853.jpg
#   inflating: /content/dataset/test/test/72c70306aace54ba95d9e65eae05f7eb.jpg
#   inflating: /content/dataset/test/test/72e2febe065d177b01564edeb420e24b.jpg
#   inflating: /content/dataset/test/test/72e9246c83fe4ce50d2d99018043ccc2.jpg
#   inflating: /content/dataset/test/test/72f9f788233f2c319950f11f67450fb5.jpg
#   inflating: /content/dataset/test/test/7333062e0a7cdba6d37007962f07ce8a.jpg
#   inflating: /content/dataset/test/test/734c9a93f9d8f98d7f2b8fb03750850b.jpg
#   inflating: /content/dataset/test/test/73754651e5cb0081c4a706369847691c.jpg
#   inflating: /content/dataset/test/test/73850da74e36edc89fc7536763f22b4d.jpg
#   inflating: /content/dataset/test/test/739c636d03d3257e003edc941272d68f.jpg
#   inflating: /content/dataset/test/test/73f11ac25272679272816f98e19f47e8.jpg
#   inflating: /content/dataset/test/test/74042e64360d296aa8e70008c8d3efc0.jpg
#   inflating: /content/dataset/test/test/7494f71845aa6663c050f6c029fd2f1d.jpg
#   inflating: /content/dataset/test/test/74a2d7b3c01c63f68614c48270507f89.jpg
#   inflating: /content/dataset/test/test/74c640f21d94d59eec3ac37cebaedd2d.jpg
#   inflating: /content/dataset/test/test/74c86dff5f96b7fe466e5216d41e6d27.jpg
#   inflating: /content/dataset/test/test/74df53d12210f742427d83c8d4192094.jpg
#   inflating: /content/dataset/test/test/755bf21d14bf061df211b60e58e8e1dd.jpg
#   inflating: /content/dataset/test/test/755dc8d54e3b79614ef44c9a8434e8b9.jpg
#   inflating: /content/dataset/test/test/756b24ca24f44a02a098370acdc3ab16.jpg
# ...
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/d2561eaa981d137b29e3a058246645f4.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/d355c68d7a408adefaac774c6ff660d9.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/d58c221e8370e2658aebfc502609aa18.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/d7c15764c5a698f47809c97f8836d442.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/d80eb8dcd60ddbbadecd602d7e3234be.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/d86cdae2dec00ba68848f76dd5866374.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/da2e70d63971c00cab3691cd38065252.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/da44dfe7542fae98d719847a09822777.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/da967a336c8f7a8a8f0ee71ecc61a7cb.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/dae64acd175779ecde037eae28efd733.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/db1307168f2e1f49e21027d46d18c538.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/de6e77794b9d6b4633d45a6454e66cb2.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/de819f70d8baacc5fa74002eea84d1ce.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/deb015c236a19812c7c566c778b30337.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e052681f9ae01aa8be18a33f2a81fdd5.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e0e27fea7267d1d667081d79afdadd91.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e22fa7d3d665b0aae167876a5df06fdf.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e2881d63260ae0e2dc9d4269a9e349af.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e330d92c592d7865e93658aca6a51323.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e3570140da5abcabac462fb41a89d622.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e36a4c4eec75df99bd208175e4279e50.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e3727c5b4b75f017baf1aba0aad019e7.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e38dca5f81f4a14dd13a567fc12db728.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e4f7ad417e492ef7955e1b31b6be3cdd.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e502602902bb69fde51dd8185b272992.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e520e4def3c3276b791424d53cd3df47.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e5f60c3df54b89be09ef1f99d524e82a.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e64510bdbfd6ea6c6cee723c055e1b50.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e6dfb932c732b2bfb9e81a0922b54531.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e83a91547ae74f206135f5b5fff97b0e.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/e90a0c87b743d90740e477d96ba5d24c.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/eb6bff13a9119265b3a3bcc4474bec96.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/ebcb5f8fb40638b6e3e4159f11879a08.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/ebd661169e9b0dd0fdc2c0e7ac940a43.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/eec8c53d191fee6417cfcd4f12d415d3.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/ef8764929195f82e746759b520fdedb7.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/efc3f78778508079ddf1b39b9f09483d.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/efe90e108b7d40765e02f80e146bc36c.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f0bad4eac2969ce9efe3116bda407e70.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f2327dc6bf154de3dec0dbdb99f4468e.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f3f6c3ad40a1f6fcc3aba0d74a3de8c3.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f404798a84166b1a227fd71716ffd615.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f40db09190bb66d881ced03d2d3c2d62.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f5585807a21c71476948e6ad3f98cf82.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f5b5fc7b1af76ca2db94a3118cffc572.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f6d1989ae192d7906a36dc2fca793ad8.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f6d1f2cfcc309f1eee488ab6e98ce0c2.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f909638c31e8f182ddf042a2573a96b2.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f9097e0c41e7649d149bb79b5a15a852.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/f9c6ce09c18ab2ba730a0ed8e92b620f.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/fa467dcb4d8456e3d1b1696452951650.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/fb286549b06d7db25a7edb78c8287cf4.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/fb37df7e989131ce7a858ec25320067d.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/fce617ed190a7d97bfad65ebb6e767d7.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/fd356daecf2740e664f15b74711d0c4c.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/fe8ee2abd7e7c47824995cab624ba07e.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/fed52ed3aaaf68c38fbac9634c8f1216.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/ff3f459d66759bdb973f4af8dd17a6f3.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/ff90a72933d50ce7dfe1788e4804d203.jpg
#   inflating: /content/dataset/train/train/squamous-cell-carcinoma/ffe6dea0a2fca93de83bb3172639eea0.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/01753b8013e298aa27ca91ac721ee0a8.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/02f11821915d67f20fb15a8e8b96c1d3.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/04619369ecec27c92b5f782adfd21b05.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/16b8f543987fd7f15139f36114a238d5.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/1c31b43cce49c0e53349f4f1adb59b1d.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/1f24cd91d3536af05573c716cee9afe3.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/20cc2e089e50034c164fb3e49bad142f.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/2108e9d766f1c6ed6ad83765f576d347.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/21988edf56792632bf60230be54b4ecb.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/256e58f0e342d523cae925d1a3e55a38.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/2c41b068641c862f5f26911422ffd78f.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/2fd4888414963b05fe63544829295e3b.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/304f8ce123139ee152d5bd43415e2edc.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/306991d08929be5a1c9cad3ecc9423bf.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/3361f78e86e2c0dcd0868286fb042384.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/37c9a984fbf34057023942c77d1ddff2.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/37ef6efc7b2498d4a693e3da285fe940.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/39db1b5308e58e1e486703dcb53b33ee.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/3abf697cc51d3887c188136ef0a4d941.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/3bc65e392aaeb35c1c6d871831a2b71c.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/3cc5bf092e65969413ebb390d9c0344e.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/41815a6d1d3a27c58d42c818b2efb236.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/430f3cba46045b2e5eb12092c03b98fd.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/454e68bf5705eabf0f4d28fc1dbd77be.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/467b2ac03723ec804ecb709da4a5bb16.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/46a52b0203c2e2e10adcfdb6dd3d30a0.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/47ae0164d37b5c26a524d8b33132fcb5.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/4ef7b09678867c6921d5385ecb18aef2.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/6a9b56f5a0721bde502d526ac0128936.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/6ddff0707d6bfe84b1b4be7a7c41bf5e.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/6fe05b4958791a509557c5fc392762ce.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/701ef9d6cfb1c845baa969eb5d49e58e.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/77aa716ae6d1b7c52f7007fd36864dc2.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/7e0b3d4f2a678d812e94c1f77f9820fa.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/81c007db8cc1bc57cb08bcc00dda653b.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/846d5436d995ac586b03958fbcfc1a96.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/8718cf620c0488269eb502f2c2ed588c.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/88c8c110ade2657fbe1c840dd2494511.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/8e9b1ff865f03340b6023a68b1dd2bea.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/9140159f37dd700e5a4d25351ae805fe.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/923228f28903085907978dbba69ee1e6.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/94d83b7ef6a07cda5e0ce98dbc2a5550.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/97daccbe6d587b298b2949cf1b0a3f21.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/98bd1bb7764270260e9b3720e57fc880.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/a07d58a0a2d13823ee977d0f2c399450.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/a27211a5b0e1bbde690a3e5feb341653.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/a2cc79f44fdb6241278e3098721cf684.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/a51617e00dfdf9febbdef2b0741ee82d.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/ab28440ed0d4fd832a76b06f5d86e401.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/acfa64e67d3581bc2a1db0c5dcadf860.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/ae1dd2f408512900bb5149de7c3d6a66.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/b373d991b75e405e4d1d3b2bf805a5df.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/b791ec8f969acd3d0736ac679dea0d29.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/b995b00ca0f6e3a5ac881db2d40a5c34.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/bb2e052ba0951cf787b9e831ab2a5b10.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/becab807bbe933d1a5e84f378dfc083f.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/c0de110fb3fb880b122cc8f058b731af.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/c3758805959417fcc2d8e98a8483217f.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/c4c2e945778e09af22e5fc0a0e92bcbf.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/c654431b35ae082b8b5ec407fbdc501b.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/c85a414180c75d978fb7259f2781b72e.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/cba6bd5b134c25e21d636d87b711f662.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/cd9875059a12da6235552ef1bfe6b306.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/d13e9416a0204d2e004f93eb5f853448.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/d611911777942df51c973badfb02c4a4.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/d6e1592cd3d3cd6718b56f6d556f77c4.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/d718d651cbb1a4041ee554bd22956206.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/d7da287fc4ca06ca56fa7a77bc66ff3a.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/d962d44c1ad9d8007dd31cbc9cb6aad8.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/deba1747c5e39cae4b05d5a6e31139fa.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/df0ccf61a18dd7434630862455337495.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/e1c75dee6b18610b7d5f6e745e2d46d7.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/e485d00e33e95305b3b1bc03d0e852ed.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/e8fd022f0fbc938d8b2a44056f1bdec5.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/f1c06ae789abed0425b017fc77eb16e5.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/f45dc98e818745e359d7d25b00c91151.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/f728b8ad950fa5a36cd26cbdf9651179.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/f78395e7569fea6aa0263b0680b39fed.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/f7860a668bff417fdf35a16e8229a587.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/fa01a1c2272065c237e67fdc34b42ae9.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/fb0dcd31990c06d1c8f254ce8b0115c1.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/fb1feb5dbf0038eee9348a3740cef6f9.jpg
#   inflating: /content/dataset/train/train/superficial-spreading-melanoma-ssm/fb645ff861b4aa453c8bc1208a93184c.jpg

# %%
# Check the first few rows to understand the structure
print(train_df.head())
# Out:
#                                            file_path  \
# 0  sampled_train_data/basal-cell-carcinoma-morphe...
# 1  sampled_train_data/dermatofibroma/aug_dermatof...
# 2  sampled_train_data/squamous-cell-carcinoma/958...
# 3  sampled_train_data/mycosis-fungoides/aug_mycos...
# 4  sampled_train_data/epidermal-nevus/f2bc5704dc1...
#
#                               label  encoded_label
# 0  basal-cell-carcinoma-morpheiform              4
# 1                    dermatofibroma              5
# 2           squamous-cell-carcinoma             19
# 3                 mycosis-fungoides             15
# 4                   epidermal-nevus              9

# %%
assert os.path.exists('/content/dataset/train.csv'), "Train CSV not found!"
assert os.path.exists('/content/dataset/test.csv'), "Test CSV not found!"

# %%
print(train_df.head())
print(test_df.head())
# Out:
#                                            file_path  \
# 0  sampled_train_data/basal-cell-carcinoma-morphe...
# 1  sampled_train_data/dermatofibroma/aug_dermatof...
# 2  sampled_train_data/squamous-cell-carcinoma/958...
# 3  sampled_train_data/mycosis-fungoides/aug_mycos...
# 4  sampled_train_data/epidermal-nevus/f2bc5704dc1...
#
#                               label  encoded_label
# 0  basal-cell-carcinoma-morpheiform              4
# 1                    dermatofibroma              5
# 2           squamous-cell-carcinoma             19
# 3                 mycosis-fungoides             15
# 4                   epidermal-nevus              9
#                                 md5hash  fitzpatrick_scale  \
# 0  0844ae634f0e6e7ef1f73c2aeecbae0e.jpg                  2
# 1  3b290d262098f761d719aa07cf36c040.jpg                  4
# 2  cf561d08ac46d0fda678bff6621005ee.jpg                  2
# 3  e6371069be05c6b0a95b4b3f1bacc9a5.jpg                  4
# 4  f76cddb37265f97508f159078dcc7e7c.jpg                  5
#
#    fitzpatrick_centaur   qc  ddi_scale  \
# 0                    2  NaN         12
# 1                    3  NaN         34
# 2                    3  NaN         12
# 3                    3  NaN         34
# 4                    5  NaN         56
#
#                                            file_path
# 0  /content/dataset/test/test/0844ae634f0e6e7ef1f...
# 1  /content/dataset/test/test/3b290d262098f761d71...
# 2  /content/dataset/test/test/cf561d08ac46d0fda67...
# 3  /content/dataset/test/test/e6371069be05c6b0a95...
# 4  /content/dataset/test/test/f76cddb37265f97508f...

# %%
print("Train CSV shape:", train_df.shape)
print("Test CSV shape:", test_df.shape)
# Out:
# Train CSV shape: (8400, 3)
# Test CSV shape: (1227, 6)

# %%
missing_files = train_df[~train_df["file_path"].apply(os.path.exists)]
print(f"Missing train images: {len(missing_files)}")
print(missing_files.head())
# Out:
# Missing train images: 8400
#                                            file_path  \
# 0  sampled_train_data/basal-cell-carcinoma-morphe...
# 1  sampled_train_data/dermatofibroma/aug_dermatof...
# 2  sampled_train_data/squamous-cell-carcinoma/958...
# 3  sampled_train_data/mycosis-fungoides/aug_mycos...
# 4  sampled_train_data/epidermal-nevus/f2bc5704dc1...
#
#                               label  encoded_label
# 0  basal-cell-carcinoma-morpheiform              4
# 1                    dermatofibroma              5
# 2           squamous-cell-carcinoma             19
# 3                 mycosis-fungoides             15
# 4                   epidermal-nevus              9

# %%
print(train_df["label"].value_counts())
# Out:
# label
# basal-cell-carcinoma-morpheiform      400
# dermatofibroma                        400
# squamous-cell-carcinoma               400
# mycosis-fungoides                     400
# epidermal-nevus                       400
# actinic-keratosis                     400
# acne                                  400
# dyshidrotic-eczema                    400
# prurigo-nodularis                     400
# eczema                                400
# melanoma                              400
# basal-cell-carcinoma                  400
# folliculitis                          400
# superficial-spreading-melanoma-ssm    400
# keloid                                400
# pyogenic-granuloma                    400
# malignant-melanoma                    400
# kaposi-sarcoma                        400
# seborrheic-keratosis                  400
# dermatomyositis                       400
# acne-vulgaris                         400
# Name: count, dtype: int64

# %%
print("Unique labels:", train_df["label"].nunique())
# Out:
# Unique labels: 21

# %%
print("Train generator class indices:", train_generator.class_indices)
print("Validation generator class indices:", val_generator.class_indices)
print("Label encoder classes:", label_encoder.classes_)
# Out:
# Train generator class indices: {}
# Validation generator class indices: {}
# Label encoder classes: ['acne' 'acne-vulgaris' 'actinic-keratosis' 'basal-cell-carcinoma'
#  'basal-cell-carcinoma-morpheiform' 'dermatofibroma' 'dermatomyositis'
#  'dyshidrotic-eczema' 'eczema' 'epidermal-nevus' 'folliculitis'
#  'kaposi-sarcoma' 'keloid' 'malignant-melanoma' 'melanoma'
#  'mycosis-fungoides' 'prurigo-nodularis' 'pyogenic-granuloma'
#  'seborrheic-keratosis' 'squamous-cell-carcinoma'
#  'superficial-spreading-melanoma-ssm']

# %%
print(train_generator.class_indices)
print(label_encoder.classes_)
# Out:
# {}
# ['acne' 'acne-vulgaris' 'actinic-keratosis' 'basal-cell-carcinoma'
#  'basal-cell-carcinoma-morpheiform' 'dermatofibroma' 'dermatomyositis'
#  'dyshidrotic-eczema' 'eczema' 'epidermal-nevus' 'folliculitis'
#  'kaposi-sarcoma' 'keloid' 'malignant-melanoma' 'melanoma'
#  'mycosis-fungoides' 'prurigo-nodularis' 'pyogenic-granuloma'
#  'seborrheic-keratosis' 'squamous-cell-carcinoma'
#  'superficial-spreading-melanoma-ssm']

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(train_df['file_path'].iloc[0])

plt.imshow(img)
plt.axis('off')  # Hide axes
plt.title(f"Label: {train_df['label'].iloc[0]}")
plt.show()

# %%
import os
import random
import shutil
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img




# Referenced FINAL-BT-sampling_data.ipynb

TARGET_SAMPLE_SIZE = 400

augmenter = ImageDataGenerator( # we use this image augmentation if we need extra images to meet TARGET_SAMPLE_SIZE
    rotation_range=40,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=0.25,
    zoom_range=0.35,
    horizontal_flip=True,
    brightness_range=[0.6, 1.5],
    fill_mode="nearest"
)

def augment_image(image_path):
    """Applies random augmentation to an image and returns a new image."""
    img = load_img(image_path)
    img_array = img_to_array(img)
    img_array = img_array.reshape((1,) + img_array.shape)
    aug_iter = augmenter.flow(img_array, batch_size=1)
    aug_img = next(aug_iter)[0]
    return array_to_img(aug_img)

def sample_files_from_directories(base_dir):
    """
    Ensures each class has exactly `TARGET_SAMPLE_SIZE` images.
    - If a class has more, randomly sample `TARGET_SAMPLE_SIZE` images.
    - If a class has fewer, use augmentation to generate new images.
    """
    sampled_files = {}

    for class_dir in tqdm(os.listdir(base_dir), desc="Processing classes"):
        class_path = os.path.join(base_dir, class_dir)
        filenames = os.listdir(class_path)

        # If class has enough images, randomly sample 200
        if len(filenames) >= TARGET_SAMPLE_SIZE:
            sampled_files[class_dir] = random.sample(filenames, TARGET_SAMPLE_SIZE)
        else:
            # Keep all original images
            sampled_files[class_dir] = filenames[:]

            # Generate new images if needed
            num_needed = TARGET_SAMPLE_SIZE - len(filenames)
            for i in range(num_needed):
                original_img = random.choice(filenames)
                new_img = augment_image(os.path.join(class_path, original_img))
                new_filename = f"aug_{class_dir}_{i}_{original_img}"
                new_img.save(os.path.join(class_path, new_filename))
                sampled_files[class_dir].append(new_filename)

    return sampled_files

import shutil

def copy_sampled_files(base_dir, sampled_files, new_dir):
    """
    Copies the selected and augmented files into a new directory with the same class-based folder structure.
    """
    os.makedirs(new_dir, exist_ok=True)

    for class_label, files in tqdm(sampled_files.items(), desc="Copying sampled files"):
        sample_dir = os.path.join(new_dir, class_label)
        os.makedirs(sample_dir, exist_ok=True)

        for file_name in files:
            src_path = os.path.join(base_dir, class_label, file_name)
            dest_path = os.path.join(sample_dir, file_name)

            if os.path.isfile(src_path):
                shutil.copy2(src_path, dest_path)

# %%
base_dir = '/content/dataset/train/train/' # Old path for the dataset
new_dir = 'sampled_train_data'

# Sample files then copy them into new_dir
sampled_files = sample_files_from_directories(base_dir)
copy_sampled_files(base_dir, sampled_files, new_dir)
# Out:
# Processing classes: 100%|██████████| 21/21 [09:25<00:00, 26.94s/it]
# Copying sampled files: 100%|██████████| 21/21 [00:02<00:00, 10.25it/s]

# %%
# Rebuild the DataFrame using the balanced images in sampled_train_data
import glob
from tensorflow.keras.applications.efficientnet import preprocess_input

image_paths = glob.glob('sampled_train_data/*/*.jpg') + glob.glob('sampled_train_data/*/*.png')  # support png too
data = {'file_path': [], 'label': []}

for path in image_paths:
    class_name = os.path.basename(os.path.dirname(path))  # class is the folder name
    data['file_path'].append(path)
    data['label'].append(class_name)

# Create new train_df from balanced sampled data
train_df = pd.DataFrame(data)
train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)  # shuffle

# Encode new labels
label_encoder = LabelEncoder()
train_df["encoded_label"] = label_encoder.fit_transform(train_df["label"])
train_df["encoded_label"] = train_df["encoded_label"].astype(str)

# Split the new balanced dataset
train_data, val_data = train_test_split(
    train_df, test_size=0.2, stratify=train_df["encoded_label"], random_state=42
)


# Define image data generators for training and validation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=False,
    brightness_range=[0.6, 1.4],
    fill_mode="nearest"
)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# Define the directory paths
train_dir = 'sampled_train_data'

# %%
def create_generator(datagen, dataframe, directory, batch_size=32, target_size=(128, 128), shuffle=True): # Enable different generators for train, val, test sets
    """
    Template function to create image generators.
    Students should complete this function to load images and labels properly.
    """
    # Fill in the correct flow_from_dataframe parameters
    generator = datagen.flow_from_dataframe(
        dataframe=dataframe,
        directory=None,
        x_col='file_path',  # Use combined path
        y_col='encoded_label',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='sparse', # Not raw because we have integer labels
        validate_filenames=True,  # Disable strict filename validation
        shuffle=shuffle
    )
    return generator

# %%
# Create generators
train_generator = create_generator(train_datagen, train_data, '', shuffle=True)
val_generator = create_generator(val_datagen, val_data, '', shuffle=False)
# Out:
# Found 6720 validated image filenames belonging to 21 classes.
# Found 1680 validated image filenames belonging to 21 classes.

# %%
print(train_df['label'].value_counts())
# Out:
# label
# basal-cell-carcinoma-morpheiform      400
# dermatofibroma                        400
# squamous-cell-carcinoma               400
# mycosis-fungoides                     400
# epidermal-nevus                       400
# actinic-keratosis                     400
# acne                                  400
# dyshidrotic-eczema                    400
# prurigo-nodularis                     400
# eczema                                400
# melanoma                              400
# basal-cell-carcinoma                  400
# folliculitis                          400
# superficial-spreading-melanoma-ssm    400
# keloid                                400
# pyogenic-granuloma                    400
# malignant-melanoma                    400
# kaposi-sarcoma                        400
# seborrheic-keratosis                  400
# dermatomyositis                       400
# acne-vulgaris                         400
# Name: count, dtype: int64

# %%
import os

missing = train_df[~train_df['file_path'].apply(os.path.exists)]
print(f"Missing image paths: {len(missing)}")
# Out:
# Missing image paths: 0

# %%
print("Train samples found:", train_generator.samples)
print("Val samples found:", val_generator.samples)
# Out:
# Train samples found: 6720
# Val samples found: 1680

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, Callback
from sklearn.metrics import f1_score
import numpy as np

# Custom F1 score callback
class F1ScoreCallback(Callback):
    def __init__(self, val_generator, steps):
        super().__init__()
        self.val_generator = val_generator
        self.steps = steps

    def on_epoch_end(self, epoch, logs=None):
        val_preds = []
        val_labels = []
        self.val_generator.reset()

        for _ in range(self.steps):
            batch_x, batch_y = next(self.val_generator)
            preds = self.model.predict(batch_x, verbose=0)
            val_preds.extend(np.argmax(preds, axis=1))
            val_labels.extend(batch_y)

        f1 = f1_score(val_labels, val_preds, average='weighted')
        print(f"\nEpoch {epoch+1} Weighted F1 Score: {f1:.4f}")

# Build base model
base_model = EfficientNetB3(weights='imagenet', include_top=False, input_shape=(128, 128, 3))
for layer in base_model.layers:
    layer.trainable = False

# Build custom head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.4)(x)
x = Dense(512, activation='swish')(x)
x = Dropout(0.3)(x)
output = Dense(21, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.3, min_lr=1e-6, verbose=1)
checkpoint = ModelCheckpoint(
    filepath='best_model_b3_initial.keras',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)
val_steps = len(val_generator)
f1_callback = F1ScoreCallback(val_generator, val_steps)

# Train
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10,
    callbacks=[early_stopping, reduce_lr, f1_callback, checkpoint],
    verbose=1
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 128, 128, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization             │ (None, 128, 128, 3)    │              7 │ rescaling[0][0]        │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling_1 (Rescaling)   │ (None, 128, 128, 3)    │              0 │ normalization[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv_pad             │ (None, 129, 129, 3)    │              0 │ rescaling_1[0][0]      │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv (Conv2D)        │ (None, 64, 64, 40)     │          1,080 │ stem_conv_pad[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_bn                   │ (None, 64, 64, 40)     │            160 │ stem_conv[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_activation           │ (None, 64, 64, 40)     │              0 │ stem_bn[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_dwconv            │ (None, 64, 64, 40)     │            360 │ stem_activation[0][0]  │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_bn                │ (None, 64, 64, 40)     │            160 │ block1a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_activation        │ (None, 64, 64, 40)     │              0 │ block1a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_squeeze        │ (None, 40)             │              0 │ block1a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reshape        │ (None, 1, 1, 40)       │              0 │ block1a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reduce         │ (None, 1, 1, 10)       │            410 │ block1a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_expand         │ (None, 1, 1, 40)       │            440 │ block1a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_excite         │ (None, 64, 64, 40)     │              0 │ block1a_activation[0]… │
# │ (Multiply)                │                        │                │ block1a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_conv      │ (None, 64, 64, 24)     │            960 │ block1a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_bn        │ (None, 64, 64, 24)     │             96 │ block1a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_dwconv            │ (None, 64, 64, 24)     │            216 │ block1a_project_bn[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_bn                │ (None, 64, 64, 24)     │             96 │ block1b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_activation        │ (None, 64, 64, 24)     │              0 │ block1b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_squeeze        │ (None, 24)             │              0 │ block1b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_reshape        │ (None, 1, 1, 24)       │              0 │ block1b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_reduce         │ (None, 1, 1, 6)        │            150 │ block1b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_expand         │ (None, 1, 1, 24)       │            168 │ block1b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_excite         │ (None, 64, 64, 24)     │              0 │ block1b_activation[0]… │
# │ (Multiply)                │                        │                │ block1b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_conv      │ (None, 64, 64, 24)     │            576 │ block1b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_bn        │ (None, 64, 64, 24)     │             96 │ block1b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_drop (Dropout)    │ (None, 64, 64, 24)     │              0 │ block1b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_add (Add)         │ (None, 64, 64, 24)     │              0 │ block1b_drop[0][0],    │
# │                           │                        │                │ block1a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_conv       │ (None, 64, 64, 144)    │          3,456 │ block1b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_bn         │ (None, 64, 64, 144)    │            576 │ block2a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_activation │ (None, 64, 64, 144)    │              0 │ block2a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv_pad        │ (None, 65, 65, 144)    │              0 │ block2a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv            │ (None, 32, 32, 144)    │          1,296 │ block2a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_bn                │ (None, 32, 32, 144)    │            576 │ block2a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_activation        │ (None, 32, 32, 144)    │              0 │ block2a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_squeeze        │ (None, 144)            │              0 │ block2a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reshape        │ (None, 1, 1, 144)      │              0 │ block2a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reduce         │ (None, 1, 1, 6)        │            870 │ block2a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_expand         │ (None, 1, 1, 144)      │          1,008 │ block2a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_excite         │ (None, 32, 32, 144)    │              0 │ block2a_activation[0]… │
# │ (Multiply)                │                        │                │ block2a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_conv      │ (None, 32, 32, 32)     │          4,608 │ block2a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_bn        │ (None, 32, 32, 32)     │            128 │ block2a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_conv       │ (None, 32, 32, 192)    │          6,144 │ block2a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_bn         │ (None, 32, 32, 192)    │            768 │ block2b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_activation │ (None, 32, 32, 192)    │              0 │ block2b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_dwconv            │ (None, 32, 32, 192)    │          1,728 │ block2b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_bn                │ (None, 32, 32, 192)    │            768 │ block2b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_activation        │ (None, 32, 32, 192)    │              0 │ block2b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_squeeze        │ (None, 192)            │              0 │ block2b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_excite         │ (None, 32, 32, 192)    │              0 │ block2b_activation[0]… │
# │ (Multiply)                │                        │                │ block2b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_conv      │ (None, 32, 32, 32)     │          6,144 │ block2b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_bn        │ (None, 32, 32, 32)     │            128 │ block2b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_drop (Dropout)    │ (None, 32, 32, 32)     │              0 │ block2b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_add (Add)         │ (None, 32, 32, 32)     │              0 │ block2b_drop[0][0],    │
# │                           │                        │                │ block2a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_conv       │ (None, 32, 32, 192)    │          6,144 │ block2b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_bn         │ (None, 32, 32, 192)    │            768 │ block2c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_activation │ (None, 32, 32, 192)    │              0 │ block2c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_dwconv            │ (None, 32, 32, 192)    │          1,728 │ block2c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_bn                │ (None, 32, 32, 192)    │            768 │ block2c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_activation        │ (None, 32, 32, 192)    │              0 │ block2c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_squeeze        │ (None, 192)            │              0 │ block2c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_excite         │ (None, 32, 32, 192)    │              0 │ block2c_activation[0]… │
# │ (Multiply)                │                        │                │ block2c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_conv      │ (None, 32, 32, 32)     │          6,144 │ block2c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_bn        │ (None, 32, 32, 32)     │            128 │ block2c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_drop (Dropout)    │ (None, 32, 32, 32)     │              0 │ block2c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_add (Add)         │ (None, 32, 32, 32)     │              0 │ block2c_drop[0][0],    │
# │                           │                        │                │ block2b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_conv       │ (None, 32, 32, 192)    │          6,144 │ block2c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_bn         │ (None, 32, 32, 192)    │            768 │ block3a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_activation │ (None, 32, 32, 192)    │              0 │ block3a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv_pad        │ (None, 35, 35, 192)    │              0 │ block3a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv            │ (None, 16, 16, 192)    │          4,800 │ block3a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_bn                │ (None, 16, 16, 192)    │            768 │ block3a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_activation        │ (None, 16, 16, 192)    │              0 │ block3a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_squeeze        │ (None, 192)            │              0 │ block3a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reshape        │ (None, 1, 1, 192)      │              0 │ block3a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block3a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block3a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_excite         │ (None, 16, 16, 192)    │              0 │ block3a_activation[0]… │
# │ (Multiply)                │                        │                │ block3a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_conv      │ (None, 16, 16, 48)     │          9,216 │ block3a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_bn        │ (None, 16, 16, 48)     │            192 │ block3a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_conv       │ (None, 16, 16, 288)    │         13,824 │ block3a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_bn         │ (None, 16, 16, 288)    │          1,152 │ block3b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_activation │ (None, 16, 16, 288)    │              0 │ block3b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_dwconv            │ (None, 16, 16, 288)    │          7,200 │ block3b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_bn                │ (None, 16, 16, 288)    │          1,152 │ block3b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_activation        │ (None, 16, 16, 288)    │              0 │ block3b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_squeeze        │ (None, 288)            │              0 │ block3b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reshape        │ (None, 1, 1, 288)      │              0 │ block3b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reduce         │ (None, 1, 1, 12)       │          3,468 │ block3b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_expand         │ (None, 1, 1, 288)      │          3,744 │ block3b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_excite         │ (None, 16, 16, 288)    │              0 │ block3b_activation[0]… │
# │ (Multiply)                │                        │                │ block3b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_conv      │ (None, 16, 16, 48)     │         13,824 │ block3b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_bn        │ (None, 16, 16, 48)     │            192 │ block3b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_drop (Dropout)    │ (None, 16, 16, 48)     │              0 │ block3b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_add (Add)         │ (None, 16, 16, 48)     │              0 │ block3b_drop[0][0],    │
# │                           │                        │                │ block3a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_conv       │ (None, 16, 16, 288)    │         13,824 │ block3b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_bn         │ (None, 16, 16, 288)    │          1,152 │ block3c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_activation │ (None, 16, 16, 288)    │              0 │ block3c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_dwconv            │ (None, 16, 16, 288)    │          7,200 │ block3c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_bn                │ (None, 16, 16, 288)    │          1,152 │ block3c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_activation        │ (None, 16, 16, 288)    │              0 │ block3c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_squeeze        │ (None, 288)            │              0 │ block3c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_reshape        │ (None, 1, 1, 288)      │              0 │ block3c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_reduce         │ (None, 1, 1, 12)       │          3,468 │ block3c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_expand         │ (None, 1, 1, 288)      │          3,744 │ block3c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_excite         │ (None, 16, 16, 288)    │              0 │ block3c_activation[0]… │
# │ (Multiply)                │                        │                │ block3c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_conv      │ (None, 16, 16, 48)     │         13,824 │ block3c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_bn        │ (None, 16, 16, 48)     │            192 │ block3c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_drop (Dropout)    │ (None, 16, 16, 48)     │              0 │ block3c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_add (Add)         │ (None, 16, 16, 48)     │              0 │ block3c_drop[0][0],    │
# │                           │                        │                │ block3b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_conv       │ (None, 16, 16, 288)    │         13,824 │ block3c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_bn         │ (None, 16, 16, 288)    │          1,152 │ block4a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_activation │ (None, 16, 16, 288)    │              0 │ block4a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv_pad        │ (None, 17, 17, 288)    │              0 │ block4a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv            │ (None, 8, 8, 288)      │          2,592 │ block4a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_bn                │ (None, 8, 8, 288)      │          1,152 │ block4a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_activation        │ (None, 8, 8, 288)      │              0 │ block4a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_squeeze        │ (None, 288)            │              0 │ block4a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reshape        │ (None, 1, 1, 288)      │              0 │ block4a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reduce         │ (None, 1, 1, 12)       │          3,468 │ block4a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_expand         │ (None, 1, 1, 288)      │          3,744 │ block4a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_excite         │ (None, 8, 8, 288)      │              0 │ block4a_activation[0]… │
# │ (Multiply)                │                        │                │ block4a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_conv      │ (None, 8, 8, 96)       │         27,648 │ block4a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_bn        │ (None, 8, 8, 96)       │            384 │ block4a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_conv       │ (None, 8, 8, 576)      │         55,296 │ block4a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_bn         │ (None, 8, 8, 576)      │          2,304 │ block4b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_activation │ (None, 8, 8, 576)      │              0 │ block4b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_dwconv            │ (None, 8, 8, 576)      │          5,184 │ block4b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_bn                │ (None, 8, 8, 576)      │          2,304 │ block4b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_activation        │ (None, 8, 8, 576)      │              0 │ block4b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_squeeze        │ (None, 576)            │              0 │ block4b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reshape        │ (None, 1, 1, 576)      │              0 │ block4b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reduce         │ (None, 1, 1, 24)       │         13,848 │ block4b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_expand         │ (None, 1, 1, 576)      │         14,400 │ block4b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_excite         │ (None, 8, 8, 576)      │              0 │ block4b_activation[0]… │
# │ (Multiply)                │                        │                │ block4b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_conv      │ (None, 8, 8, 96)       │         55,296 │ block4b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_bn        │ (None, 8, 8, 96)       │            384 │ block4b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_drop (Dropout)    │ (None, 8, 8, 96)       │              0 │ block4b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_add (Add)         │ (None, 8, 8, 96)       │              0 │ block4b_drop[0][0],    │
# │                           │                        │                │ block4a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_conv       │ (None, 8, 8, 576)      │         55,296 │ block4b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_bn         │ (None, 8, 8, 576)      │          2,304 │ block4c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_activation │ (None, 8, 8, 576)      │              0 │ block4c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_dwconv            │ (None, 8, 8, 576)      │          5,184 │ block4c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_bn                │ (None, 8, 8, 576)      │          2,304 │ block4c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_activation        │ (None, 8, 8, 576)      │              0 │ block4c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_squeeze        │ (None, 576)            │              0 │ block4c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reshape        │ (None, 1, 1, 576)      │              0 │ block4c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reduce         │ (None, 1, 1, 24)       │         13,848 │ block4c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_expand         │ (None, 1, 1, 576)      │         14,400 │ block4c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_excite         │ (None, 8, 8, 576)      │              0 │ block4c_activation[0]… │
# │ (Multiply)                │                        │                │ block4c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_conv      │ (None, 8, 8, 96)       │         55,296 │ block4c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_bn        │ (None, 8, 8, 96)       │            384 │ block4c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_drop (Dropout)    │ (None, 8, 8, 96)       │              0 │ block4c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_add (Add)         │ (None, 8, 8, 96)       │              0 │ block4c_drop[0][0],    │
# │                           │                        │                │ block4b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_conv       │ (None, 8, 8, 576)      │         55,296 │ block4c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_bn         │ (None, 8, 8, 576)      │          2,304 │ block4d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_activation │ (None, 8, 8, 576)      │              0 │ block4d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_dwconv            │ (None, 8, 8, 576)      │          5,184 │ block4d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_bn                │ (None, 8, 8, 576)      │          2,304 │ block4d_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │ block6f_se_expand         │ (None, 1, 1, 1392)     │         82,128 │ block6f_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_se_excite         │ (None, 4, 4, 1392)     │              0 │ block6f_activation[0]… │
# │ (Multiply)                │                        │                │ block6f_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_project_conv      │ (None, 4, 4, 232)      │        322,944 │ block6f_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_project_bn        │ (None, 4, 4, 232)      │            928 │ block6f_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_drop (Dropout)    │ (None, 4, 4, 232)      │              0 │ block6f_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6f_add (Add)         │ (None, 4, 4, 232)      │              0 │ block6f_drop[0][0],    │
# │                           │                        │                │ block6e_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_conv       │ (None, 4, 4, 1392)     │        322,944 │ block6f_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_bn         │ (None, 4, 4, 1392)     │          5,568 │ block7a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_activation │ (None, 4, 4, 1392)     │              0 │ block7a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_dwconv            │ (None, 4, 4, 1392)     │         12,528 │ block7a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_bn                │ (None, 4, 4, 1392)     │          5,568 │ block7a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_activation        │ (None, 4, 4, 1392)     │              0 │ block7a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_squeeze        │ (None, 1392)           │              0 │ block7a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_reshape        │ (None, 1, 1, 1392)     │              0 │ block7a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_reduce         │ (None, 1, 1, 58)       │         80,794 │ block7a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_expand         │ (None, 1, 1, 1392)     │         82,128 │ block7a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_excite         │ (None, 4, 4, 1392)     │              0 │ block7a_activation[0]… │
# │ (Multiply)                │                        │                │ block7a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_project_conv      │ (None, 4, 4, 384)      │        534,528 │ block7a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_project_bn        │ (None, 4, 4, 384)      │          1,536 │ block7a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_conv       │ (None, 4, 4, 2304)     │        884,736 │ block7a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_bn         │ (None, 4, 4, 2304)     │          9,216 │ block7b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_activation │ (None, 4, 4, 2304)     │              0 │ block7b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_dwconv            │ (None, 4, 4, 2304)     │         20,736 │ block7b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_bn                │ (None, 4, 4, 2304)     │          9,216 │ block7b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_activation        │ (None, 4, 4, 2304)     │              0 │ block7b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_squeeze        │ (None, 2304)           │              0 │ block7b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_reshape        │ (None, 1, 1, 2304)     │              0 │ block7b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_reduce         │ (None, 1, 1, 96)       │        221,280 │ block7b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_expand         │ (None, 1, 1, 2304)     │        223,488 │ block7b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_excite         │ (None, 4, 4, 2304)     │              0 │ block7b_activation[0]… │
# │ (Multiply)                │                        │                │ block7b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_project_conv      │ (None, 4, 4, 384)      │        884,736 │ block7b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_project_bn        │ (None, 4, 4, 384)      │          1,536 │ block7b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_drop (Dropout)    │ (None, 4, 4, 384)      │              0 │ block7b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_add (Add)         │ (None, 4, 4, 384)      │              0 │ block7b_drop[0][0],    │
# │                           │                        │                │ block7a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_conv (Conv2D)         │ (None, 4, 4, 1536)     │        589,824 │ block7b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_bn                    │ (None, 4, 4, 1536)     │          6,144 │ top_conv[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_activation            │ (None, 4, 4, 1536)     │              0 │ top_bn[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1536)           │              0 │ top_activation[0][0]   │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 1536)           │          6,144 │ global_average_poolin… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 1536)           │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 512)            │        786,944 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 512)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 21)             │         10,773 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 11,587,396 (44.20 MB)
#  Trainable params: 800,789 (3.05 MB)
#  Non-trainable params: 10,786,607 (41.15 MB)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0789 - loss: 3.8072
# Epoch 1 Weighted F1 Score: 0.2667
#
# Epoch 1: val_accuracy improved from -inf to 0.28452, saving model to best_model_b3_initial.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 535s 2s/step - accuracy: 0.0790 - loss: 3.8059 - val_accuracy: 0.2845 - val_loss: 2.4444 - learning_rate: 1.0000e-04
# Epoch 2/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1787 - loss: 3.0179
# Epoch 2 Weighted F1 Score: 0.3499
#
# Epoch 2: val_accuracy improved from 0.28452 to 0.36071, saving model to best_model_b3_initial.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 541s 2s/step - accuracy: 0.1788 - loss: 3.0176 - val_accuracy: 0.3607 - val_loss: 2.1552 - learning_rate: 1.0000e-04
# Epoch 3/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2363 - loss: 2.7396
# Epoch 3 Weighted F1 Score: 0.3919
#
# Epoch 3: val_accuracy improved from 0.36071 to 0.40000, saving model to best_model_b3_initial.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 502s 2s/step - accuracy: 0.2363 - loss: 2.7395 - val_accuracy: 0.4000 - val_loss: 2.0085 - learning_rate: 1.0000e-04
# Epoch 4/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2683 - loss: 2.5966
# Epoch 4 Weighted F1 Score: 0.4195
#
# Epoch 4: val_accuracy improved from 0.40000 to 0.42560, saving model to best_model_b3_initial.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 481s 2s/step - accuracy: 0.2683 - loss: 2.5965 - val_accuracy: 0.4256 - val_loss: 1.9024 - learning_rate: 1.0000e-04
# Epoch 5/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2856 - loss: 2.4686
# Epoch 5 Weighted F1 Score: 0.4492
#
# Epoch 5: val_accuracy improved from 0.42560 to 0.45595, saving model to best_model_b3_initial.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 477s 2s/step - accuracy: 0.2856 - loss: 2.4686 - val_accuracy: 0.4560 - val_loss: 1.8234 - learning_rate: 1.0000e-04
# Epoch 6/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3141 - loss: 2.3366
# Epoch 6 Weighted F1 Score: 0.4713
#
# Epoch 6: val_accuracy improved from 0.45595 to 0.47679, saving model to best_model_b3_initial.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 474s 2s/step - accuracy: 0.3140 - loss: 2.3367 - val_accuracy: 0.4768 - val_loss: 1.7495 - learning_rate: 1.0000e-04
# Epoch 7/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3311 - loss: 2.2959
# Epoch 7 Weighted F1 Score: 0.4786
#
# Epoch 7: val_accuracy improved from 0.47679 to 0.48452, saving model to best_model_b3_initial.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 486s 2s/step - accuracy: 0.3311 - loss: 2.2959 - val_accuracy: 0.4845 - val_loss: 1.7121 - learning_rate: 1.0000e-04
# Epoch 8/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3359 - loss: 2.2258
# Epoch 8 Weighted F1 Score: 0.4921
#
# Epoch 8: val_accuracy improved from 0.48452 to 0.49762, saving model to best_model_b3_initial.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 463s 2s/step - accuracy: 0.3360 - loss: 2.2258 - val_accuracy: 0.4976 - val_loss: 1.6895 - learning_rate: 1.0000e-04
# Epoch 9/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3603 - loss: 2.1633
# Epoch 9 Weighted F1 Score: 0.4948
#
# Epoch 9: val_accuracy improved from 0.49762 to 0.49881, saving model to best_model_b3_initial.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 498s 2s/step - accuracy: 0.3603 - loss: 2.1635 - val_accuracy: 0.4988 - val_loss: 1.6394 - learning_rate: 1.0000e-04
# Epoch 10/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3673 - loss: 2.1527
# Epoch 10 Weighted F1 Score: 0.5069
#
# Epoch 10: val_accuracy improved from 0.49881 to 0.51190, saving model to best_model_b3_initial.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.3673 - loss: 2.1526 - val_accuracy: 0.5119 - val_loss: 1.6001 - learning_rate: 1.0000e-04

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, Callback
from sklearn.metrics import f1_score
import numpy as np

# Unfreeze all layers for fine-tuning
for layer in model.layers:
    layer.trainable = True

# Recompile with lower learning rate
model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# Callbacks for fine-tuning
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.2, min_lr=1e-7, verbose=1)
checkpoint = ModelCheckpoint(
    filepath='best_model_b3_finetuned.keras',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)
val_steps = len(val_generator)
f1_callback = F1ScoreCallback(val_generator, val_steps)

# Fine-tune
history_finetune = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20,
    callbacks=[early_stopping, reduce_lr, f1_callback, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1630 - loss: 3.0293
# Epoch 1 Weighted F1 Score: 0.3541
#
# Epoch 1: val_accuracy improved from -inf to 0.36071, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1616s 7s/step - accuracy: 0.1631 - loss: 3.0291 - val_accuracy: 0.3607 - val_loss: 2.1380 - learning_rate: 1.0000e-05
# Epoch 2/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1989 - loss: 2.9138
# Epoch 2 Weighted F1 Score: 0.3333
#
# Epoch 2: val_accuracy did not improve from 0.36071
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1479s 7s/step - accuracy: 0.1989 - loss: 2.9135 - val_accuracy: 0.3405 - val_loss: 2.2167 - learning_rate: 1.0000e-05
# Epoch 3/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2292 - loss: 2.7146
# Epoch 3 Weighted F1 Score: 0.3401
#
# Epoch 3: val_accuracy did not improve from 0.36071
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1412s 7s/step - accuracy: 0.2292 - loss: 2.7147 - val_accuracy: 0.3500 - val_loss: 2.1555 - learning_rate: 1.0000e-05
# Epoch 4/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2427 - loss: 2.6916
# Epoch 4 Weighted F1 Score: 0.3592
#
# Epoch 4: val_accuracy improved from 0.36071 to 0.37083, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1585s 7s/step - accuracy: 0.2428 - loss: 2.6914 - val_accuracy: 0.3708 - val_loss: 2.0853 - learning_rate: 1.0000e-05
# Epoch 5/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2591 - loss: 2.6004
# Epoch 5 Weighted F1 Score: 0.3829
#
# Epoch 5: val_accuracy improved from 0.37083 to 0.39583, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1630s 8s/step - accuracy: 0.2592 - loss: 2.6002 - val_accuracy: 0.3958 - val_loss: 2.0213 - learning_rate: 1.0000e-05
# Epoch 6/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2918 - loss: 2.4933
# Epoch 6 Weighted F1 Score: 0.3930
#
# Epoch 6: val_accuracy improved from 0.39583 to 0.40536, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1453s 7s/step - accuracy: 0.2918 - loss: 2.4932 - val_accuracy: 0.4054 - val_loss: 1.9650 - learning_rate: 1.0000e-05
# Epoch 7/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3038 - loss: 2.4170
# Epoch 7 Weighted F1 Score: 0.4115
#
# Epoch 7: val_accuracy improved from 0.40536 to 0.42381, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1453s 7s/step - accuracy: 0.3038 - loss: 2.4170 - val_accuracy: 0.4238 - val_loss: 1.9149 - learning_rate: 1.0000e-05
# Epoch 8/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3154 - loss: 2.3973
# Epoch 8 Weighted F1 Score: 0.4271
#
# Epoch 8: val_accuracy improved from 0.42381 to 0.43869, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1441s 7s/step - accuracy: 0.3154 - loss: 2.3971 - val_accuracy: 0.4387 - val_loss: 1.8640 - learning_rate: 1.0000e-05
# Epoch 9/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3249 - loss: 2.3139
# Epoch 9 Weighted F1 Score: 0.4431
#
# Epoch 9: val_accuracy improved from 0.43869 to 0.45357, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1487s 7s/step - accuracy: 0.3249 - loss: 2.3138 - val_accuracy: 0.4536 - val_loss: 1.8133 - learning_rate: 1.0000e-05
# Epoch 10/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3400 - loss: 2.2678
# Epoch 10 Weighted F1 Score: 0.4501
#
# Epoch 10: val_accuracy improved from 0.45357 to 0.46131, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1470s 7s/step - accuracy: 0.3401 - loss: 2.2676 - val_accuracy: 0.4613 - val_loss: 1.7719 - learning_rate: 1.0000e-05
# Epoch 11/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3563 - loss: 2.2070
# Epoch 11 Weighted F1 Score: 0.4640
#
# Epoch 11: val_accuracy improved from 0.46131 to 0.47440, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1447s 7s/step - accuracy: 0.3563 - loss: 2.2069 - val_accuracy: 0.4744 - val_loss: 1.7274 - learning_rate: 1.0000e-05
# Epoch 12/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3547 - loss: 2.1767
# Epoch 12 Weighted F1 Score: 0.4800
#
# Epoch 12: val_accuracy improved from 0.47440 to 0.49048, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1438s 7s/step - accuracy: 0.3548 - loss: 2.1767 - val_accuracy: 0.4905 - val_loss: 1.6861 - learning_rate: 1.0000e-05
# Epoch 13/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3769 - loss: 2.1225
# Epoch 13 Weighted F1 Score: 0.4950
#
# Epoch 13: val_accuracy improved from 0.49048 to 0.50476, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1423s 7s/step - accuracy: 0.3769 - loss: 2.1224 - val_accuracy: 0.5048 - val_loss: 1.6441 - learning_rate: 1.0000e-05
# Epoch 14/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3788 - loss: 2.0623
# Epoch 14 Weighted F1 Score: 0.5050
#
# Epoch 14: val_accuracy improved from 0.50476 to 0.51429, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1430s 7s/step - accuracy: 0.3788 - loss: 2.0621 - val_accuracy: 0.5143 - val_loss: 1.6147 - learning_rate: 1.0000e-05
# Epoch 15/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4120 - loss: 1.9892
# Epoch 15 Weighted F1 Score: 0.5138
#
# Epoch 15: val_accuracy improved from 0.51429 to 0.52381, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1434s 7s/step - accuracy: 0.4120 - loss: 1.9892 - val_accuracy: 0.5238 - val_loss: 1.5770 - learning_rate: 1.0000e-05
# Epoch 16/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4202 - loss: 1.9607
# Epoch 16 Weighted F1 Score: 0.5267
#
# Epoch 16: val_accuracy improved from 0.52381 to 0.53631, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1435s 7s/step - accuracy: 0.4202 - loss: 1.9607 - val_accuracy: 0.5363 - val_loss: 1.5394 - learning_rate: 1.0000e-05
# Epoch 17/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4057 - loss: 1.9550
# Epoch 17 Weighted F1 Score: 0.5321
#
# Epoch 17: val_accuracy improved from 0.53631 to 0.54107, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1466s 7s/step - accuracy: 0.4058 - loss: 1.9548 - val_accuracy: 0.5411 - val_loss: 1.5075 - learning_rate: 1.0000e-05
# Epoch 18/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4330 - loss: 1.8927
# Epoch 18 Weighted F1 Score: 0.5456
#
# Epoch 18: val_accuracy improved from 0.54107 to 0.55417, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1464s 7s/step - accuracy: 0.4330 - loss: 1.8927 - val_accuracy: 0.5542 - val_loss: 1.4833 - learning_rate: 1.0000e-05
# Epoch 19/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4308 - loss: 1.8774
# Epoch 19 Weighted F1 Score: 0.5554
#
# Epoch 19: val_accuracy improved from 0.55417 to 0.56488, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1448s 7s/step - accuracy: 0.4309 - loss: 1.8773 - val_accuracy: 0.5649 - val_loss: 1.4490 - learning_rate: 1.0000e-05
# Epoch 20/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4475 - loss: 1.8463
# Epoch 20 Weighted F1 Score: 0.5600
#
# Epoch 20: val_accuracy improved from 0.56488 to 0.56964, saving model to best_model_b3_finetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1480s 7s/step - accuracy: 0.4475 - loss: 1.8463 - val_accuracy: 0.5696 - val_loss: 1.4198 - learning_rate: 1.0000e-05

# %%
import joblib
import pickle
import json

# save model
model.save('final_efficientnetb3_model.keras')

# save label encoder
with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(label_encoder, f)

# save train/val dataframes
train_df.to_csv('train_df.csv', index=False)
train_data.to_csv('train_data.csv', index=False)
val_data.to_csv('val_data.csv', index=False)

# save the training history
with open('history_finetune.json', 'w') as f:
    json.dump(history_finetune.history, f)

# %%
# !zip -r model_backup.zip final_efficientnetb3_model.keras best_model_b3_finetuned.keras label_encoder.pkl train_df.csv train_data.csv val_data.csv history_finetune.json
# Out:
#   adding: final_efficientnetb3_model.keras (deflated 9%)
#   adding: best_model_b3_finetuned.keras (deflated 9%)
#   adding: label_encoder.pkl (deflated 33%)
#   adding: train_df.csv (deflated 78%)
#   adding: train_data.csv (deflated 78%)
#   adding: val_data.csv (deflated 78%)
#   adding: history_finetune.json (deflated 61%)

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, Callback
from sklearn.metrics import f1_score
import numpy as np

# load previous model
model = load_model('final_efficientnetb3_model.keras')  # or use 'best_model_b3_finetuned.keras'

# unfreeze every layer
for layer in model.layers:
    layer.trainable = True

# recompile the model with a lower learning rate for safe convergence
model.compile(
    optimizer=Adam(learning_rate=5e-6),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


class F1ScoreCallback(Callback):
    def __init__(self, val_generator, steps):
        super().__init__()
        self.val_generator = val_generator
        self.steps = steps

    def on_epoch_end(self, epoch, logs=None):
        val_preds = []
        val_labels = []
        self.val_generator.reset()
        for _ in range(self.steps):
            batch_x, batch_y = next(self.val_generator)
            preds = self.model.predict(batch_x, verbose=0)
            val_preds.extend(np.argmax(preds, axis=1))
            val_labels.extend(batch_y)
        f1 = f1_score(val_labels, val_preds, average='weighted')
        print(f"\nEpoch {epoch+1} Weighted F1 Score: {f1:.4f}")

early_stopping = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.3, min_lr=1e-7, verbose=1)
checkpoint = ModelCheckpoint(
    filepath='best_model_b3_refinetuned.keras',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)

val_steps = len(val_generator)
f1_callback = F1ScoreCallback(val_generator, val_steps)

history_refine = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10,
    callbacks=[early_stopping, reduce_lr, f1_callback, checkpoint],
    verbose=1
)

# save the final version after retuning it
model.save('final_efficientnetb3_model_refined.keras')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4224 - loss: 1.9607
# Epoch 1 Weighted F1 Score: 0.5555
#
# Epoch 1: val_accuracy improved from -inf to 0.56369, saving model to best_model_b3_refinetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1475s 7s/step - accuracy: 0.4223 - loss: 1.9606 - val_accuracy: 0.5637 - val_loss: 1.3723 - learning_rate: 5.0000e-06
# Epoch 2/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4324 - loss: 1.9094
# Epoch 2 Weighted F1 Score: 0.5629
#
# Epoch 2: val_accuracy improved from 0.56369 to 0.57143, saving model to best_model_b3_refinetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1374s 7s/step - accuracy: 0.4323 - loss: 1.9094 - val_accuracy: 0.5714 - val_loss: 1.3618 - learning_rate: 5.0000e-06
# Epoch 3/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4315 - loss: 1.8770
# Epoch 3 Weighted F1 Score: 0.5604
#
# Epoch 3: val_accuracy did not improve from 0.57143
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1377s 7s/step - accuracy: 0.4315 - loss: 1.8769 - val_accuracy: 0.5690 - val_loss: 1.3447 - learning_rate: 5.0000e-06
# Epoch 4/10
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4417 - loss: 1.8708
# Epoch 4 Weighted F1 Score: 0.5691
#
# Epoch 4: val_accuracy improved from 0.57143 to 0.57857, saving model to best_model_b3_refinetuned.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1365s 6s/step - accuracy: 0.4418 - loss: 1.8708 - val_accuracy: 0.5786 - val_loss: 1.3306 - learning_rate: 5.0000e-06
# Epoch 5/10
# 133/210 ━━━━━━━━━━━━━━━━━━━━ 7:20 6s/step - accuracy: 0.4327 - loss: 1.8756

# %%
print("Unique labels in training data:", train_df["label"].unique())
print("Total number of unique labels:", train_df["label"].nunique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8fd62d9fd877> in <cell line: 0>()
# ----> 1 print("Unique labels in training data:", train_df["label"].unique())
#       2 print("Total number of unique labels:", train_df["label"].nunique())
#
# NameError: name 'train_df' is not defined

# %%
import os

missing_files = [path for path in train_df["file_path"] if not os.path.exists(path)]
print(f"Total missing files: {len(missing_files)} out of {len(train_df)}")

# Print a few example missing files
if missing_files:
    print("Example missing files:", missing_files[:5])
# Out:
# Total missing files: 0 out of 8400

# %%
# 6. Make Predictions on Test Data
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def preprocess_test_data(test_df, directory):
    """
    Template for loading and preprocessing test images.
    """
    # TODO: create a generator for the test set here.
    test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
    test_generator = test_datagen.flow_from_dataframe(dataframe=test_df, directory=None, x_col='file_path', target_size=(128, 128), batch_size=64, class_mode=None, shuffle=False)
    return test_generator

# %%
import os

# Check a few sample paths
print("Sample train file paths:")
print(train_df["file_path"].head())

# Verify if the paths exist
missing_files = [path for path in train_df["file_path"] if not os.path.exists(path)]
print(f"Total missing files: {len(missing_files)} out of {len(train_df)}")
if missing_files:
    print("Example missing files:", missing_files[:5])
# Out:
# Sample train file paths:
# 0    /content/dataset/train/train/prurigo-nodularis...
# 1    /content/dataset/train/train/basal-cell-carcin...
# 2    /content/dataset/train/train/keloid/c94ce27e38...
# 3    /content/dataset/train/train/basal-cell-carcin...
# 4    /content/dataset/train/train/prurigo-nodularis...
# Name: file_path, dtype: object
# Total missing files: 0 out of 2860

# %%
# Load test data
test_dir = '/kaggle/input/bttai-ajl-2025/test/test/'
test_generator = preprocess_test_data(test_df, test_dir)
# Out:
# Found 1227 validated image filenames.

# %%
predictions = model.predict(test_generator, verbose=1)
predicted_class_indices = np.argmax(predictions, axis=1)
class_labels = label_encoder.inverse_transform(predicted_class_indices)

# removing `.jpg` from file names to get only md5hash values
cleaned_hashes = test_df["file_path"].apply(lambda path: os.path.splitext(os.path.basename(path))[0])

prediction_df = pd.DataFrame({
    "md5hash": cleaned_hashes,
    "label": class_labels
})

prediction_df.to_csv("submission-four.csv", index=False)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step

# %%
num_rows = prediction_df.shape[0]
print(f"The number of rows in the predictions DataFrame is: {num_rows}")
# Out:
# The number of rows in the predictions DataFrame is: 1227
